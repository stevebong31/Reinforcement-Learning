# %%
import numpy as np
import tensorflow as tf
import random
from collections import deque
import gym

# %%
env = gym.make('CartPole-v0')
env._max_episode_steps = 10001

# Constant defining our neural network
input_size = env.observation_space.shape[0] # 4개 상태
output_size = env.action_space.n # 2개 action

dis = 0.9
REPLAY_MEMORY = 50000
# Out:
# C:\Users\HW-steve\Anaconda3\lib\site-packages\gym\envs\registration.py:14: PkgResourcesDeprecationWarning: Parameters to load are deprecated.  Call .resolve and .require separately.
#   result = entry_point.load(False)

# %%
class DQN:
    def __init__(self, session, input_size, output_size, name="main"):
        self.session = session
        self.input_size = input_size
        self.output_size = output_size
        self.net_name = name
        self._build_network()

    def _build_network(self, h_size=10, l_rate=0.1):
        with tf.variable_scope(self.net_name):
            self._X = tf.placeholder(
                tf.float32, [None, self.input_size], name="input_x")

            # First layer of weights
            W1 = tf.get_variable("W1", shape=[self.input_size, h_size],
                                 initializer=tf.contrib.layers.xavier_initializer())
            layer1 = tf.nn.tanh(tf.matmul(self._X, W1))

            # Second layer of Weights
            W2 = tf.get_variable("W2", shape=[h_size, self.output_size],
                                 initializer=tf.contrib.layers.xavier_initializer())

            # Q prediction
            self._Qpred = tf.matmul(layer1, W2)

        # We need to define the parts of the network needed for learning a policy
        self._Y = tf.placeholder(
            shape=[None, self.output_size], dtype=tf.float32)

        # Loss function
        self._loss = tf.reduce_mean(tf.square(self._Y - self._Qpred))
        # Learning
        self._train = tf.train.AdamOptimizer(
            learning_rate=l_rate).minimize(self._loss)

    def predict(self, state):
        x = np.reshape(state, [1, self.input_size])
        return self.session.run(self._Qpred, feed_dict={self._X:x})

    def update(self, x_stack, y_stack):
        return self.session.run([self._loss, self._train],
                                feed_dict={self._X: x_stack, self._Y: y_stack})

# %%
def replay_train(mainDQN, targetDQN, train_batch):
    x_stack = np.empty(0).reshape(0, input_size)  # 한번에 모아서 학습하기 위한 자료구조
    y_stack = np.empty(0).reshape(0, output_size)

    # Get stored information from the buffer
    for state, action, reward, next_state, done in train_batch:
        Q = mainDQN.predict(state)

        if done:  # terminal?
            Q[0, action] = reward
        else:
            # get target from targetDQN
            Q[0, action] = reward + dis * np.max(targetDQN.predict(next_state))

        y_stack = np.vstack([y_stack, Q])
        x_stack = np.vstack([x_stack, state])

    # Train our network using target and predicted Q values on each episode
    return mainDQN.update(x_stack, y_stack)

# %%
def get_copy_var_ops(dest_scope_name="target", src_scope_name="main"):
    # Copy variables src_scope to dest_scope
    op_holder = []
    src_vars = tf.get_collection(
        tf.GraphKeys.TRAINABLE_VARIABLES, scope=src_scope_name
    )
    dest_vars = tf.get_collection(
        tf.GraphKeys.TRAINABLE_VARIABLES, scope=dest_scope_name
    )

    for src_vars, dest_vars in zip(src_vars, dest_vars):
        op_holder.append(dest_vars.assign(src_vars.value()))

    return op_holder

# %%
def bot_play(mainDQN):
    # See our trained network in action
    s = env.reset()
    reward_sum = 0
    while True:
        env.render()
        a = np.argmax(mainDQN.predict(s))
        s, reward, done, _ = env.step(a)
        reward_sum += reward
        if done:
            print ("Total score {} ".format(reward_sum))
            break

# %%
def main():
    max_episode = 5000
    # store the previous obervations in the replay memory
    replay_buffer = deque()
    with tf.Session() as sess:
        mainDQN = DQN(sess, input_size, output_size, name="main")
        targetDQN = DQN(sess, input_size, output_size, name="target")
        tf.global_variables_initializer().run()

        # initial copy q_net -> target_net
        copy_ops = get_copy_var_ops(dest_scope_name="target", src_scope_name="main")
        sess.run(copy_ops)

        for episode in range(max_episode):
            e = 1. /((episode / 10) + 1)
            done = False
            step_count = 0
            state = env.reset()
            while not done:
                if np.random.rand(1) < e:
                    action = env.action_space.sample()
                else:
                    action = np.argmax(mainDQN.predict(state))

                # Get new state and reward from environment
                next_state, reward, done, _ = env.step(action)
                if done:
                    reward = -100 # big penalty

                # Save the experience to our buffer
                replay_buffer.append((state, action, reward, next_state, done))
                if len(replay_buffer) > REPLAY_MEMORY:
                    replay_buffer.popleft()

                state = next_state
                step_count += 1
                if reward > 100: # good enough(막대가 넘어지지 않고 잘 유지되는 횟수)
                    break

            print ("Episode: {} steps {}".format(episode, step_count))
            if step_count > 10000:
                pass

            bot_play(mainDQN)
                
            if episode % 10 ==1: # train every 10 episode
                # Get a random batch of experience
                for _ in range(50):
                    # Minibatch works better
                    minibatch = random.sample(replay_buffer, 10)
                    loss, _ = replay_train(mainDQN, targetDQN,  minibatch)
                print ("Loss : ", loss)

                # Copy q_net -> target_net
                sess.run(copy_ops)

# %%
if __name__ == "__main__":
    main()
# Out:
# Episode: 0 steps 14
# Total score 9.0
# Episode: 1 steps 10
# Total score 9.0
# Loss :  2.0488803
# Episode: 2 steps 35
# Total score 18.0
# Episode: 3 steps 13
# Total score 19.0
# Episode: 4 steps 14
# Total score 20.0
# Episode: 5 steps 22
# Total score 19.0
# Episode: 6 steps 39
# Total score 17.0
# Episode: 7 steps 19
# Total score 19.0
# Episode: 8 steps 33
# Total score 14.0
# Episode: 9 steps 25
# Total score 17.0
# Episode: 10 steps 34
# Total score 16.0
# Episode: 11 steps 23
# Total score 63.0
# Loss :  541.12537
# Episode: 12 steps 16
# Total score 10.0
# Episode: 13 steps 12
# Total score 10.0
# Episode: 14 steps 9
# Total score 8.0
# Episode: 15 steps 9
# Total score 10.0
# Episode: 16 steps 12
# Total score 10.0
# Episode: 17 steps 12
# Total score 10.0
# Episode: 18 steps 10
# Total score 9.0
# Episode: 19 steps 9
# Total score 10.0
# Episode: 20 steps 15
# Total score 10.0
# Episode: 21 steps 9
# Total score 9.0
# Loss :  472.9051
# Episode: 22 steps 11
# Total score 10.0
# Episode: 23 steps 14
# Total score 10.0
# Episode: 24 steps 11
# Total score 11.0
# Episode: 25 steps 15
# Total score 11.0
# Episode: 26 steps 12
# Total score 10.0
# Episode: 27 steps 14
# Total score 10.0
# Episode: 28 steps 15
# Total score 10.0
# Episode: 29 steps 12
# Total score 10.0
# Episode: 30 steps 9
# Total score 10.0
# Episode: 31 steps 11
# Total score 10.0
# Loss :  6.5975447
# Episode: 32 steps 56
# Total score 46.0
# Episode: 33 steps 68
# Total score 63.0
# Episode: 34 steps 35
# Total score 103.0
# Episode: 35 steps 47
# Total score 109.0
# Episode: 36 steps 64
# Total score 113.0
# Episode: 37 steps 49
# Total score 139.0
# Episode: 38 steps 82
# Total score 63.0
# Episode: 39 steps 86
# Total score 97.0
# Episode: 40 steps 53
# Total score 132.0
# Episode: 41 steps 69
# Total score 72.0
# Loss :  497.14517
# Episode: 42 steps 72
# Total score 84.0
# Episode: 43 steps 84
# Total score 79.0
# Episode: 44 steps 92
# Total score 112.0
# Episode: 45 steps 78
# Total score 108.0
# Episode: 46 steps 74
# Total score 68.0
# Episode: 47 steps 78
# Total score 86.0
# Episode: 48 steps 101
# Total score 60.0
# Episode: 49 steps 131
# Total score 71.0
# Episode: 50 steps 59
# Total score 89.0
# Episode: 51 steps 66
# Total score 52.0
# Loss :  508.93073
# Episode: 52 steps 67
# Total score 51.0
# Episode: 53 steps 95
# Total score 109.0
# Episode: 54 steps 132
# Total score 68.0
# Episode: 55 steps 96
# Total score 62.0
# Episode: 56 steps 42
# Total score 64.0
# Episode: 57 steps 96
# Total score 54.0
# Episode: 58 steps 51
# Total score 45.0
# Episode: 59 steps 60
# Total score 61.0
# Episode: 60 steps 155
# Total score 44.0
# Episode: 61 steps 50
# Total score 70.0
# Loss :  508.77457
# Episode: 62 steps 24
# Total score 39.0
# Episode: 63 steps 48
# Total score 40.0
# Episode: 64 steps 24
# Total score 45.0
# Episode: 65 steps 58
# Total score 31.0
# Episode: 66 steps 45
# Total score 49.0
# Episode: 67 steps 33
# Total score 22.0
# Episode: 68 steps 36
# Total score 30.0
# Episode: 69 steps 29
# Total score 21.0
# Episode: 70 steps 39
# Total score 53.0
# Episode: 71 steps 29
# Total score 86.0
# Loss :  2.7523925
# Episode: 72 steps 12
# Total score 9.0
# Episode: 73 steps 9
# Total score 9.0
# Episode: 74 steps 9
# Total score 10.0
# Episode: 75 steps 9
# Total score 9.0
# Episode: 76 steps 10
# Total score 10.0
# Episode: 77 steps 10
# Total score 10.0
# Episode: 78 steps 8
# Total score 9.0
# Episode: 79 steps 8
# Total score 10.0
# Episode: 80 steps 9
# Total score 8.0
# Episode: 81 steps 10
# Total score 9.0
# Loss :  9.064514
# Episode: 82 steps 34
# Total score 24.0
# Episode: 83 steps 104
# Total score 39.0
# Episode: 84 steps 37
# Total score 28.0
# Episode: 85 steps 67
# Total score 71.0
# Episode: 86 steps 126
# Total score 52.0
# Episode: 87 steps 31
# Total score 46.0
# Episode: 88 steps 74
# Total score 46.0
# Episode: 89 steps 41
# Total score 47.0
# Episode: 90 steps 76
# Total score 70.0
# Episode: 91 steps 36
# Total score 40.0
# Loss :  3.5356479
# Episode: 92 steps 31
# Total score 39.0
# Episode: 93 steps 89
# Total score 29.0
# Episode: 94 steps 49
# Total score 97.0
# Episode: 95 steps 48
# Total score 79.0
# Episode: 96 steps 47
# Total score 27.0
# Episode: 97 steps 43
# Total score 55.0
# Episode: 98 steps 41
# Total score 28.0
# Episode: 99 steps 47
# Total score 30.0
# Episode: 100 steps 55
# Total score 32.0
# Episode: 101 steps 36
# Total score 95.0
# Loss :  3.224095
# Episode: 102 steps 39
# Total score 32.0
# Episode: 103 steps 31
# Total score 22.0
# Episode: 104 steps 24
# Total score 21.0
# Episode: 105 steps 20
# Total score 34.0
# Episode: 106 steps 27
# Total score 22.0
# Episode: 107 steps 21
# Total score 34.0
# Episode: 108 steps 25
# Total score 25.0
# Episode: 109 steps 39
# Total score 22.0
# Episode: 110 steps 32
# Total score 38.0
# Episode: 111 steps 28
# Total score 31.0
# Loss :  8.820562
# Episode: 112 steps 46
# Total score 24.0
# Episode: 113 steps 34
# Total score 43.0
# Episode: 114 steps 37
# Total score 23.0
# Episode: 115 steps 22
# Total score 20.0
# Episode: 116 steps 25
# Total score 60.0
# Episode: 117 steps 37
# Total score 36.0
# Episode: 118 steps 48
# Total score 40.0
# Episode: 119 steps 50
# Total score 61.0
# Episode: 120 steps 39
# Total score 30.0
# Episode: 121 steps 45
# Total score 26.0
# Loss :  1.9764769
# Episode: 122 steps 39
# Total score 38.0
# Episode: 123 steps 39
# Total score 42.0
# Episode: 124 steps 39
# Total score 71.0
# Episode: 125 steps 43
# Total score 36.0
# Episode: 126 steps 40
# Total score 28.0
# Episode: 127 steps 46
# Total score 36.0
# Episode: 128 steps 82
# Total score 85.0
# Episode: 129 steps 58
# Total score 29.0
# Episode: 130 steps 38
# Total score 34.0
# Episode: 131 steps 67
# Total score 40.0
# Loss :  6.642092
# Episode: 132 steps 12
# Total score 12.0
# Episode: 133 steps 10
# Total score 10.0
# Episode: 134 steps 10
# Total score 9.0
# Episode: 135 steps 9
# Total score 10.0
# Episode: 136 steps 10
# Total score 11.0
# Episode: 137 steps 10
# Total score 8.0
# Episode: 138 steps 10
# Total score 10.0
# Episode: 139 steps 9
# Total score 11.0
# Episode: 140 steps 15
# Total score 8.0
# Episode: 141 steps 11
# Total score 9.0
# Loss :  4.7250333
# Episode: 142 steps 68
# Total score 43.0
# Episode: 143 steps 69
# Total score 49.0
# Episode: 144 steps 51
# Total score 48.0
# Episode: 145 steps 38
# Total score 41.0
# Episode: 146 steps 64
# Total score 66.0
# Episode: 147 steps 39
# Total score 52.0
# Episode: 148 steps 90
# Total score 54.0
# Episode: 149 steps 82
# Total score 71.0
# Episode: 150 steps 86
# Total score 62.0
# Episode: 151 steps 39
# Total score 45.0
# Loss :  4.2809424
# Episode: 152 steps 256
# Total score 158.0
# Episode: 153 steps 192
# Total score 206.0
# Episode: 154 steps 170
# Total score 138.0
# Episode: 155 steps 126
# Total score 171.0
# Episode: 156 steps 207
# Total score 150.0
# Episode: 157 steps 145
# Total score 136.0
# Episode: 158 steps 163
# Total score 167.0
# Episode: 159 steps 110
# Total score 150.0
# Episode: 160 steps 189
# Total score 125.0
# Episode: 161 steps 122
# Total score 120.0
# Loss :  2.8237758
# Episode: 162 steps 143
# Total score 178.0
# Episode: 163 steps 159
# Total score 197.0
# Episode: 164 steps 226
# Total score 194.0
# Episode: 165 steps 228
# Total score 230.0
# Episode: 166 steps 172
# Total score 155.0
# Episode: 167 steps 150
# Total score 305.0
# Episode: 168 steps 141
# Total score 190.0
# Episode: 169 steps 145
# Total score 124.0
# Episode: 170 steps 201
# Total score 197.0
# Episode: 171 steps 219
# Total score 191.0
# Loss :  10.012896
# Episode: 172 steps 98
# Total score 130.0
# Episode: 173 steps 124
# Total score 424.0
# Episode: 174 steps 101
# Total score 146.0
# Episode: 175 steps 181
# Total score 150.0
# Episode: 176 steps 112
# Total score 111.0
# Episode: 177 steps 136
# Total score 110.0
# Episode: 178 steps 196
# Total score 108.0
# Episode: 179 steps 178
# Total score 146.0
# Episode: 180 steps 322
# Total score 80.0
# Episode: 181 steps 118
# Total score 112.0
# Loss :  3.9219773
# Episode: 182 steps 25
# Total score 26.0
# Episode: 183 steps 33
# Total score 28.0
# Episode: 184 steps 26
# Total score 22.0
# Episode: 185 steps 24
# Total score 38.0
# Episode: 186 steps 26
# Total score 26.0
# Episode: 187 steps 26
# Total score 28.0
# Episode: 188 steps 34
# Total score 22.0
# Episode: 189 steps 34
# Total score 24.0
# Episode: 190 steps 44
# Total score 52.0
# Episode: 191 steps 27
# Total score 26.0
# Loss :  1.6006104
# Episode: 192 steps 33
# Total score 30.0
# Episode: 193 steps 24
# Total score 24.0
# Episode: 194 steps 23
# Total score 24.0
# Episode: 195 steps 28
# Total score 30.0
# Episode: 196 steps 21
# Total score 27.0
# Episode: 197 steps 44
# Total score 28.0
# Episode: 198 steps 22
# Total score 25.0
# Episode: 199 steps 46
# Total score 22.0
# Episode: 200 steps 30
# Total score 23.0
# Episode: 201 steps 22
# Total score 30.0
# Loss :  0.4524177
# Episode: 202 steps 45
# Total score 67.0
# Episode: 203 steps 72
# Total score 52.0
# Episode: 204 steps 80
# Total score 43.0
# Episode: 205 steps 74
# Total score 87.0
# Episode: 206 steps 57
# Total score 49.0
# Episode: 207 steps 51
# Total score 42.0
# Episode: 208 steps 56
# Total score 49.0
# Episode: 209 steps 101
# Total score 71.0
# Episode: 210 steps 35
# Total score 75.0
# Episode: 211 steps 59
# Total score 53.0
# Loss :  1.6270964
# Episode: 212 steps 9
# Total score 8.0
# Episode: 213 steps 8
# Total score 9.0
# Episode: 214 steps 9
# Total score 8.0
# Episode: 215 steps 9
# Total score 9.0
# Episode: 216 steps 9
# Total score 9.0
# Episode: 217 steps 10
# Total score 9.0
# Episode: 218 steps 9
# Total score 8.0
# Episode: 219 steps 9
# Total score 9.0
# Episode: 220 steps 9
# Total score 8.0
# Episode: 221 steps 9
# Total score 9.0
# Loss :  0.5442877
# Episode: 222 steps 32
# Total score 34.0
# Episode: 223 steps 40
# Total score 28.0
# Episode: 224 steps 29
# Total score 50.0
# Episode: 225 steps 38
# Total score 71.0
# Episode: 226 steps 29
# Total score 27.0
# Episode: 227 steps 23
# Total score 36.0
# Episode: 228 steps 29
# Total score 56.0
# Episode: 229 steps 39
# Total score 54.0
# Episode: 230 steps 30
# Total score 39.0
# Episode: 231 steps 23
# Total score 21.0
# Loss :  2.7774673
# Episode: 232 steps 80
# Total score 120.0
# Episode: 233 steps 126
# Total score 120.0
# Episode: 234 steps 74
# Total score 114.0
# Episode: 235 steps 81
# Total score 124.0
# Episode: 236 steps 152
# Total score 117.0
# Episode: 237 steps 116
# Total score 113.0
# Episode: 238 steps 114
# Total score 84.0
# Episode: 239 steps 107
# Total score 129.0
# Episode: 240 steps 85
# Total score 124.0
# Episode: 241 steps 70
# Total score 109.0
# Loss :  8.644014
# Episode: 242 steps 20
# Total score 16.0
# Episode: 243 steps 38
# Total score 14.0
# Episode: 244 steps 88
# Total score 20.0
# Episode: 245 steps 20
# Total score 27.0
# Episode: 246 steps 25
# Total score 20.0
# Episode: 247 steps 20
# Total score 17.0
# Episode: 248 steps 17
# Total score 25.0
# Episode: 249 steps 18
# Total score 21.0
# Episode: 250 steps 16
# Total score 40.0
# Episode: 251 steps 19
# Total score 21.0
# Loss :  1.6461775
# Episode: 252 steps 25
# Total score 33.0
# Episode: 253 steps 34
# Total score 27.0
# Episode: 254 steps 32
# Total score 20.0
# Episode: 255 steps 24
# Total score 18.0
# Episode: 256 steps 29
# Total score 21.0
# Episode: 257 steps 32
# Total score 23.0
# Episode: 258 steps 20
# Total score 20.0
# Episode: 259 steps 24
# Total score 22.0
# Episode: 260 steps 23
# Total score 38.0
# Episode: 261 steps 21
# Total score 26.0
# Loss :  1.609017
# Episode: 262 steps 11
# Total score 15.0
# Episode: 263 steps 10
# Total score 10.0
# Episode: 264 steps 16
# Total score 11.0
# Episode: 265 steps 13
# Total score 10.0
# Episode: 266 steps 12
# Total score 13.0
# Episode: 267 steps 14
# Total score 13.0
# Episode: 268 steps 10
# Total score 12.0
# Episode: 269 steps 10
# Total score 10.0
# Episode: 270 steps 11
# Total score 11.0
# Episode: 271 steps 15
# Total score 11.0
# Loss :  3.7085583
# Episode: 272 steps 61
# Total score 35.0
# Episode: 273 steps 56
# Total score 64.0
# Episode: 274 steps 25
# Total score 66.0
# Episode: 275 steps 24
# Total score 56.0
# Episode: 276 steps 51
# Total score 23.0
# Episode: 277 steps 63
# Total score 61.0
# Episode: 278 steps 52
# Total score 59.0
# Episode: 279 steps 25
# Total score 58.0
# Episode: 280 steps 62
# Total score 32.0
# Episode: 281 steps 26
# Total score 38.0
# Loss :  2.1485958
# Episode: 282 steps 10
# Total score 12.0
# Episode: 283 steps 19
# Total score 14.0
# Episode: 284 steps 16
# Total score 13.0
# Episode: 285 steps 26
# Total score 10.0
# Episode: 286 steps 15
# Total score 12.0
# Episode: 287 steps 13
# Total score 15.0
# Episode: 288 steps 20
# Total score 13.0
# Episode: 289 steps 13
# Total score 9.0
# Episode: 290 steps 14
# Total score 14.0
# Episode: 291 steps 15
# Total score 12.0
# Loss :  5.2403684
# Episode: 292 steps 66
# Total score 102.0
# Episode: 293 steps 59
# Total score 74.0
# Episode: 294 steps 66
# Total score 69.0
# Episode: 295 steps 52
# Total score 142.0
# Episode: 296 steps 75
# Total score 64.0
# Episode: 297 steps 57
# Total score 98.0
# Episode: 298 steps 76
# Total score 57.0
# Episode: 299 steps 97
# Total score 46.0
# Episode: 300 steps 74
# Total score 76.0
# Episode: 301 steps 74
# Total score 97.0
# Loss :  4.2702303
# Episode: 302 steps 12
# Total score 9.0
# Episode: 303 steps 9
# Total score 9.0
# Episode: 304 steps 9
# Total score 10.0
# Episode: 305 steps 10
# Total score 8.0
# Episode: 306 steps 9
# Total score 9.0
# Episode: 307 steps 11
# Total score 10.0
# Episode: 308 steps 9
# Total score 10.0
# Episode: 309 steps 10
# Total score 8.0
# Episode: 310 steps 10
# Total score 9.0
# Episode: 311 steps 10
# Total score 9.0
# Loss :  525.0849
# Episode: 312 steps 60
# Total score 195.0
# Episode: 313 steps 80
# Total score 115.0
# Episode: 314 steps 182
# Total score 55.0
# Episode: 315 steps 134
# Total score 53.0
# Episode: 316 steps 64
# Total score 151.0
# Episode: 317 steps 189
# Total score 61.0
# Episode: 318 steps 108
# Total score 145.0
# Episode: 319 steps 55
# Total score 56.0
# Episode: 320 steps 47
# Total score 178.0
# Episode: 321 steps 356
# Total score 142.0
# Loss :  8.764383
# Episode: 322 steps 48
# Total score 45.0
# Episode: 323 steps 43
# Total score 32.0
# Episode: 324 steps 49
# Total score 29.0
# Episode: 325 steps 40
# Total score 35.0
# Episode: 326 steps 57
# Total score 32.0
# Episode: 327 steps 34
# Total score 54.0
# Episode: 328 steps 33
# Total score 51.0
# Episode: 329 steps 101
# Total score 31.0
# Episode: 330 steps 75
# Total score 35.0
# Episode: 331 steps 31
# Total score 34.0
# Loss :  6.838229
# Episode: 332 steps 20
# Total score 35.0
# Episode: 333 steps 27
# Total score 27.0
# Episode: 334 steps 25
# Total score 27.0
# Episode: 335 steps 23
# Total score 24.0
# Episode: 336 steps 25
# Total score 27.0
# Episode: 337 steps 23
# Total score 25.0
# Episode: 338 steps 25
# Total score 20.0
# Episode: 339 steps 21
# Total score 23.0
# Episode: 340 steps 25
# Total score 26.0
# Episode: 341 steps 19
# Total score 23.0
# Loss :  2.60522
# Episode: 342 steps 27
# Total score 44.0
# Episode: 343 steps 21
# Total score 25.0
# Episode: 344 steps 36
# Total score 35.0
# Episode: 345 steps 29
# Total score 32.0
# Episode: 346 steps 35
# Total score 25.0
# Episode: 347 steps 37
# Total score 43.0
# Episode: 348 steps 50
# Total score 34.0
# Episode: 349 steps 35
# Total score 43.0
# Episode: 350 steps 27
# Total score 29.0
# Episode: 351 steps 32
# Total score 34.0
# Loss :  2.4164035
# Episode: 352 steps 61
# Total score 63.0
# Episode: 353 steps 170
# Total score 73.0
# Episode: 354 steps 45
# Total score 48.0
# Episode: 355 steps 60
# Total score 108.0
# Episode: 356 steps 62
# Total score 146.0
# Episode: 357 steps 61
# Total score 52.0
# Episode: 358 steps 88
# Total score 51.0
# Episode: 359 steps 63
# Total score 138.0
# Episode: 360 steps 160
# Total score 143.0
# Episode: 361 steps 69
# Total score 119.0
# Loss :  527.9813
# Episode: 362 steps 23
# Total score 12.0
# Episode: 363 steps 24
# Total score 11.0
# Episode: 364 steps 22
# Total score 27.0
# Episode: 365 steps 12
# Total score 23.0
# Episode: 366 steps 11
# Total score 21.0
# Episode: 367 steps 20
# Total score 23.0
# Episode: 368 steps 17
# Total score 11.0
# Episode: 369 steps 23
# Total score 11.0
# Episode: 370 steps 29
# Total score 27.0
# Episode: 371 steps 11
# Total score 24.0
# Loss :  2.8110187
# Episode: 372 steps 8
# Total score 8.0
# Episode: 373 steps 10
# Total score 9.0
# Episode: 374 steps 8
# Total score 9.0
# Episode: 375 steps 8
# Total score 8.0
# Episode: 376 steps 9
# Total score 9.0
# Episode: 377 steps 9
# Total score 8.0
# Episode: 378 steps 9
# Total score 9.0
# Episode: 379 steps 10
# Total score 8.0
# Episode: 380 steps 9
# Total score 9.0
# Episode: 381 steps 10
# Total score 8.0
# Loss :  447.49298
# Episode: 382 steps 9
# Total score 9.0
# Episode: 383 steps 12
# Total score 9.0
# Episode: 384 steps 9
# Total score 11.0
# Episode: 385 steps 14
# Total score 11.0
# Episode: 386 steps 10
# Total score 8.0
# Episode: 387 steps 9
# Total score 8.0
# Episode: 388 steps 9
# Total score 11.0
# Episode: 389 steps 9
# Total score 8.0
# Episode: 390 steps 11
# Total score 8.0
# Episode: 391 steps 9
# Total score 9.0
# Loss :  5.428008
# Episode: 392 steps 37
# Total score 57.0
# Episode: 393 steps 26
# Total score 88.0
# Episode: 394 steps 66
# Total score 52.0
# Episode: 395 steps 18
# Total score 39.0
# Episode: 396 steps 24
# Total score 16.0
# Episode: 397 steps 16
# Total score 33.0
# Episode: 398 steps 18
# Total score 24.0
# Episode: 399 steps 74
# Total score 21.0
# Episode: 400 steps 26
# Total score 31.0
# Episode: 401 steps 124
# Total score 133.0
# Loss :  2.4664986
# Episode: 402 steps 8
# Total score 10.0
# Episode: 403 steps 9
# Total score 9.0
# Episode: 404 steps 9
# Total score 9.0
# Episode: 405 steps 9
# Total score 9.0
# Episode: 406 steps 9
# Total score 9.0
# Episode: 407 steps 9
# Total score 9.0
# Episode: 408 steps 9
# Total score 9.0
# Episode: 409 steps 9
# Total score 9.0
# Episode: 410 steps 9
# Total score 8.0
# Episode: 411 steps 8
# Total score 9.0
# Loss :  2.2133126
# Episode: 412 steps 29
# Total score 34.0
# Episode: 413 steps 25
# Total score 28.0
# Episode: 414 steps 30
# Total score 28.0
# Episode: 415 steps 22
# Total score 24.0
# Episode: 416 steps 27
# Total score 51.0
# Episode: 417 steps 28
# Total score 42.0
# Episode: 418 steps 27
# Total score 27.0
# Episode: 419 steps 36
# Total score 35.0
# Episode: 420 steps 29
# Total score 23.0
# Episode: 421 steps 25
# Total score 27.0
# Loss :  5.227743
# Episode: 422 steps 26
# Total score 34.0
# Episode: 423 steps 37
# Total score 35.0
# Episode: 424 steps 23
# Total score 42.0
# Episode: 425 steps 24
# Total score 60.0
# Episode: 426 steps 37
# Total score 23.0
# Episode: 427 steps 25
# Total score 23.0
# Episode: 428 steps 45
# Total score 47.0
# Episode: 429 steps 22
# Total score 32.0
# Episode: 430 steps 25
# Total score 50.0
# Episode: 431 steps 27
# Total score 26.0
# Loss :  6.2021804
# Episode: 432 steps 9
# Total score 10.0
# Episode: 433 steps 8
# Total score 9.0
# Episode: 434 steps 8
# Total score 9.0
# Episode: 435 steps 9
# Total score 8.0
# Episode: 436 steps 10
# Total score 8.0
# Episode: 437 steps 9
# Total score 8.0
# Episode: 438 steps 9
# Total score 9.0
# Episode: 439 steps 9
# Total score 9.0
# Episode: 440 steps 9
# Total score 10.0
# Episode: 441 steps 10
# Total score 9.0
# Loss :  0.63296604
# Episode: 442 steps 24
# Total score 85.0
# Episode: 443 steps 24
# Total score 56.0
# Episode: 444 steps 29
# Total score 80.0
# Episode: 445 steps 26
# Total score 30.0
# Episode: 446 steps 24
# Total score 30.0
# Episode: 447 steps 28
# Total score 27.0
# Episode: 448 steps 32
# Total score 29.0
# Episode: 449 steps 23
# Total score 24.0
# Episode: 450 steps 30
# Total score 28.0
# Episode: 451 steps 42
# Total score 35.0
# Loss :  2.8869529
# Episode: 452 steps 30
# Total score 11.0
# Episode: 453 steps 16
# Total score 33.0
# Episode: 454 steps 61
# Total score 18.0
# Episode: 455 steps 59
# Total score 16.0
# Episode: 456 steps 21
# Total score 11.0
# Episode: 457 steps 27
# Total score 13.0
# Episode: 458 steps 37
# Total score 13.0
# Episode: 459 steps 22
# Total score 21.0
# Episode: 460 steps 19
# Total score 16.0
# Episode: 461 steps 23
# Total score 18.0
# Loss :  9.482462
# Episode: 462 steps 8
# Total score 9.0
# Episode: 463 steps 11
# Total score 8.0
# Episode: 464 steps 8
# Total score 10.0
# Episode: 465 steps 10
# Total score 9.0
# Episode: 466 steps 9
# Total score 10.0
# Episode: 467 steps 9
# Total score 10.0
# Episode: 468 steps 8
# Total score 8.0
# Episode: 469 steps 10
# Total score 9.0
# Episode: 470 steps 8
# Total score 10.0
# Episode: 471 steps 9
# Total score 8.0
# Loss :  1.7893302
# Episode: 472 steps 254
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-972361fa1b80> in <module>
#       1 if __name__ == "__main__":
# ----> 2     main()
#
# <ipython-input-7-224bd16fa3bc> in main()
#      42                 pass
#      43
# ---> 44             bot_play(mainDQN)
#      45
#      46             if episode % 10 ==1: # train every 10 episode
#
# <ipython-input-6-572ac0c1e2cb> in bot_play(mainDQN)
#       4     reward_sum = 0
#       5     while True:
# ----> 6         env.render()
#       7         a = np.argmax(mainDQN.predict(s))
#       8         s, reward, done, _ = env.step(a)
#
# ~\Anaconda3\lib\site-packages\gym\core.py in render(self, mode, **kwargs)
#     273
#     274     def render(self, mode='human', **kwargs):
# --> 275         return self.env.render(mode, **kwargs)
#     276
#     277     def close(self):
#
# ~\Anaconda3\lib\site-packages\gym\envs\classic_control\cartpole.py in render(self, mode)
#     186         self.poletrans.set_rotation(-x[2])
#     187
# --> 188         return self.viewer.render(return_rgb_array = mode=='rgb_array')
#     189
#     190     def close(self):
#
# ~\Anaconda3\lib\site-packages\gym\envs\classic_control\rendering.py in render(self, return_rgb_array)
#      80
#      81     def render(self, return_rgb_array=False):
# ---> 82         glClearColor(1,1,1,1)
#      83         self.window.clear()
#      84         self.window.switch_to()
#
# ~\Anaconda3\lib\site-packages\pyglet\gl\lib.py in errcheck(result, func, arguments)
#     100         raise GLException('No GL context; create a Window first')
#     101     if not context._gl_begin:
# --> 102         error = gl.glGetError()
#     103         if error:
#     104             msg = ctypes.cast(gl.gluErrorString(error), ctypes.c_char_p).value
#
# KeyboardInterrupt:
