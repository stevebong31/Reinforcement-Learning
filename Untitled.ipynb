# %%
from keras.layers.convolutional import Conv2D
from keras.layers import Dense, Flatten
from keras.optimizers import RMSprop
from keras.models import Sequential
from skimage.transform import resize
from skimage.color import rgb2gray
from collections import deque
from keras import backend as K
import tensorflow as tf
import numpy as np
import random
import gym
import os
# Out:
# Using TensorFlow backend.

# %%
model_path = os.path.join(os.getcwd(),'save_model')

if not os.path.isdir(model_path):
    os.mkdir(model_path)
EPISODES = 50000

# %%
class DQNAgent:
    def __init__(self, action_size):
        self.render = False
        self.load_model = False
        # 상태와 행동의 크기 정의
        self.state_size = (84, 84, 4)
        self.action_size = action_size
        # DQN 하이퍼파라미터
        self.epsilon = 1.
        self.epsilon_start, self.epsilon_end = 1.0, 0.1
        self.exploration_steps = 1000000.
        self.epsilon_decay_step = (self.epsilon_start - self.epsilon_end) \
                                  / self.exploration_steps
        self.batch_size = 32
        self.train_start = 50000
        self.update_target_rate = 10000
        self.discount_factor = 0.99
        # 리플레이 메모리, 최대 크기 400000
        self.memory = deque(maxlen=400000)
        self.no_op_steps = 30
        # 모델과 타겟모델을 생성하고 타겟모델 초기화
        self.model = self.build_model()
        self.target_model = self.build_model()
        self.update_target_model()
 
        self.optimizer = self.optimizer()
 
        # 텐서보드 설정
        self.sess = tf.InteractiveSession()
        K.set_session(self.sess)
 
        self.avg_q_max, self.avg_loss = 0, 0
        self.summary_placeholders, self.update_ops, self.summary_op = \
            self.setup_summary()
        self.summary_writer = tf.summary.FileWriter(
            'summary/breakout_dqn', self.sess.graph)
        self.sess.run(tf.global_variables_initializer())
 
        if self.load_model:
            self.model.load_weights("./save_model/breakout_dqn_trained.h5")
 
    # Huber Loss를 이용하기 위해 최적화 함수를 직접 정의
    def optimizer(self):
        a = K.placeholder(shape=(None,), dtype='int32')
        y = K.placeholder(shape=(None,), dtype='float32')
 
        prediction = self.model.output
 
        a_one_hot = K.one_hot(a, self.action_size)
        q_value = K.sum(prediction * a_one_hot, axis=1)
        error = K.abs(y - q_value)
 
        quadratic_part = K.clip(error, 0.0, 1.0)
        linear_part = error - quadratic_part
        loss = K.mean(0.5 * K.square(quadratic_part) + linear_part)
 
        optimizer = RMSprop(lr=0.00025, epsilon=0.01)
        updates = optimizer.get_updates(self.model.trainable_weights, [], loss)
        train = K.function([self.model.input, a, y], [loss], updates=updates)
 
        return train
 
    # 상태가 입력, 큐함수가 출력인 인공신경망 생성
    def build_model(self):
        model = Sequential()
        model.add(Conv2D(32, (8, 8), strides=(4, 4),
                         activation='relu',
                         input_shape=self.state_size))
        model.add(Conv2D(64, (4, 4), strides=(2, 2),
                         activation='relu'))
        model.add(Conv2D(64, (3, 3), strides=(1, 1),
                         activation='relu'))
        model.add(Flatten())
        model.add(Dense(512, activation='relu'))
        model.add(Dense(self.action_size))
        model.summary()
        return model
 
    # 타겟 모델을 모델의 가중치로 업데이트
    def update_target_model(self):
        self.target_model.set_weights(self.model.get_weights())
 
    # 입실론 탐욕 정책으로 행동 선택
    def get_action(self, history):
        history = np.float32(history / 255.0)
        if np.random.rand() <= self.epsilon:
            return random.randrange(self.action_size)
        else:
            q_value = self.model.predict(history)
            return np.argmax(q_value[0])
 
    # 샘플 <s, a, r, s'>을 리플레이 메모리에 저장
    def append_sample(self, history, action, reward, next_history, dead):
        self.memory.append((history, action, reward, next_history, dead))
 
    # 리플레이 메모리에서 무작위로 추출한 배치로 모델 학습
    def train_model(self):
        if self.epsilon > self.epsilon_end:
            self.epsilon -= self.epsilon_decay_step
 
        mini_batch = random.sample(self.memory, self.batch_size)
 
        history = np.zeros((self.batch_size, self.state_size[0],
                            self.state_size[1], self.state_size[2]))
        next_history = np.zeros((self.batch_size, self.state_size[0],
                                 self.state_size[1], self.state_size[2]))
        target = np.zeros((self.batch_size,))
        action, reward, dead = [], [], []
 
        for i in range(self.batch_size):
            history[i] = np.float32(mini_batch[i][0] / 255.)
            next_history[i] = np.float32(mini_batch[i][3] / 255.)
            action.append(mini_batch[i][1])
            reward.append(mini_batch[i][2])
            dead.append(mini_batch[i][4])
 
        target_value = self.target_model.predict(next_history)
 
        for i in range(self.batch_size):
            if dead[i]:
                target[i] = reward[i]
            else:
                target[i] = reward[i] + self.discount_factor * \
                                        np.amax(target_value[i])
 
        loss = self.optimizer([history, action, target])
        self.avg_loss += loss[0]
 
    # 각 에피소드 당 학습 정보를 기록
    def setup_summary(self):
        episode_total_reward = tf.Variable(0.)
        episode_avg_max_q = tf.Variable(0.)
        episode_duration = tf.Variable(0.)
        episode_avg_loss = tf.Variable(0.)
 
        tf.summary.scalar('Total Reward/Episode', episode_total_reward)
        tf.summary.scalar('Average Max Q/Episode', episode_avg_max_q)
        tf.summary.scalar('Duration/Episode', episode_duration)
        tf.summary.scalar('Average Loss/Episode', episode_avg_loss)
 
        summary_vars = [episode_total_reward, episode_avg_max_q,
                        episode_duration, episode_avg_loss]
        summary_placeholders = [tf.placeholder(tf.float32) for _ in
                                range(len(summary_vars))]
        update_ops = [summary_vars[i].assign(summary_placeholders[i]) for i in
                      range(len(summary_vars))]
        summary_op = tf.summary.merge_all()
        return summary_placeholders, update_ops, summary_op

# %%
def pre_processing(observe):
    processed_observe = np.uint8(
        resize(rgb2gray(observe), (84, 84), mode='constant') * 255)
    return processed_observe

# %%
if __name__ == "__main__":
    # 환경과 DQN 에이전트 생성
    env = gym.make('BreakoutDeterministic-v4')
    agent = DQNAgent(action_size=3)
 
    scores, episodes, global_step = [], [], 0
 
    for e in range(EPISODES):
        done = False
        dead = False
 
        step, score, start_life = 0, 0, 5
        observe = env.reset()
 
        for _ in range(random.randint(1, agent.no_op_steps)):
            observe, _, _, _ = env.step(1)
 
        state = pre_processing(observe)
        history = np.stack((state, state, state, state), axis=2)
        history = np.reshape([history], (1, 84, 84, 4))
 
        while not done:
            if agent.render:
                env.render()
            global_step += 1
            step += 1
 
            # 바로 전 4개의 상태로 행동을 선택
            action = agent.get_action(history)
            # 1: 정지, 2: 왼쪽, 3: 오른쪽
            if action == 0:
                real_action = 1
            elif action == 1:
                real_action = 2
            else:
                real_action = 3
 
            # 선택한 행동으로 환경에서 한 타임스텝 진행
            observe, reward, done, info = env.step(real_action)
            # 각 타임스텝마다 상태 전처리
            next_state = pre_processing(observe)
            next_state = np.reshape([next_state], (1, 84, 84, 1))
            next_history = np.append(next_state, history[:, :, :, :3], axis=3)
 
            agent.avg_q_max += np.amax(
                agent.model.predict(np.float32(history / 255.))[0])
 
            if start_life > info['ale.lives']:
                dead = True
                start_life = info['ale.lives']
 
            reward = np.clip(reward, -1., 1.)
            # 샘플 <s, a, r, s'>을 리플레이 메모리에 저장 후 학습
            agent.append_sample(history, action, reward, next_history, dead)
 
            if len(agent.memory) >= agent.train_start:
                agent.train_model()
 
            # 일정 시간마다 타겟모델을 모델의 가중치로 업데이트
            if global_step % agent.update_target_rate == 0:
                agent.update_target_model()
 
            score += reward
 
            if dead:
                dead = False
            else:
                history = next_history
 
            if done:
                # 각 에피소드 당 학습 정보를 기록
                if global_step > agent.train_start:
                    stats = [score, agent.avg_q_max / float(step), step,
                             agent.avg_loss / float(step)]
 
                    for i in range(len(stats)):
                        agent.sess.run(agent.update_ops[i], feed_dict={
                            agent.summary_placeholders[i]: float(stats[i])
                        })
                    summary_str = agent.sess.run(agent.summary_op)
                    agent.summary_writer.add_summary(summary_str, e + 1)
 
                print("episode:", e, "  score:", score, "  memory length:",
                      len(agent.memory), "  epsilon:", agent.epsilon,
                      "  global_step:", global_step, "  average_q:",
                      agent.avg_q_max / float(step), "  average loss:",
                      agent.avg_loss / float(step))
 
                agent.avg_q_max, agent.avg_loss = 0, 0
 
        # 1000 에피소드마다 모델 저장
        if e % 1000 == 0:
            agent.model.save_weights("./save_model/breakout_dqn.h5")
# Out:
# C:\Users\HW-steve\Anaconda3\lib\site-packages\gym\envs\registration.py:14: PkgResourcesDeprecationWarning: Parameters to load are deprecated.  Call .resolve and .require separately.
#   result = entry_point.load(False)
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 20, 20, 32)        8224
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 9, 9, 64)          32832
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 7, 7, 64)          36928
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 3136)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               1606144
# _________________________________________________________________
# dense_2 (Dense)              (None, 3)                 1539
# =================================================================
# Total params: 1,685,667
# Trainable params: 1,685,667
# Non-trainable params: 0
# _________________________________________________________________
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_4 (Conv2D)            (None, 20, 20, 32)        8224
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 9, 9, 64)          32832
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 7, 7, 64)          36928
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 3136)              0
# _________________________________________________________________
# dense_3 (Dense)              (None, 512)               1606144
# _________________________________________________________________
# dense_4 (Dense)              (None, 3)                 1539
# =================================================================
# Total params: 1,685,667
# Trainable params: 1,685,667
# Non-trainable params: 0
# _________________________________________________________________
# INFO:tensorflow:Summary name Total Reward/Episode is illegal; using Total_Reward/Episode instead.
# INFO:tensorflow:Summary name Average Max Q/Episode is illegal; using Average_Max_Q/Episode instead.
# INFO:tensorflow:Summary name Average Loss/Episode is illegal; using Average_Loss/Episode instead.
# C:\Users\HW-steve\Anaconda3\lib\site-packages\skimage\transform\_warps.py:110: UserWarning: Anti-aliasing will be enabled by default in skimage 0.15 to avoid aliasing artifacts when down-sampling images.
#   warn("Anti-aliasing will be enabled by default in skimage 0.15 to "
# episode: 0   score: 3.0   memory length: 259   epsilon: 1.0   global_step: 259   average_q: 0.06500755830103366   average loss: 0.0
# episode: 1   score: 0.0   memory length: 381   epsilon: 1.0   global_step: 381   average_q: 0.06435538385613043   average loss: 0.0
# episode: 2   score: 0.0   memory length: 509   epsilon: 1.0   global_step: 509   average_q: 0.06385445722844452   average loss: 0.0
# episode: 3   score: 0.0   memory length: 622   epsilon: 1.0   global_step: 622   average_q: 0.06405395285877506   average loss: 0.0
# episode: 4   score: 0.0   memory length: 725   epsilon: 1.0   global_step: 725   average_q: 0.06468751961455761   average loss: 0.0
# episode: 5   score: 1.0   memory length: 871   epsilon: 1.0   global_step: 871   average_q: 0.06422523322374854   average loss: 0.0
# episode: 6   score: 1.0   memory length: 1038   epsilon: 1.0   global_step: 1038   average_q: 0.06264332666279313   average loss: 0.0
# episode: 7   score: 3.0   memory length: 1312   epsilon: 1.0   global_step: 1312   average_q: 0.06234005466103554   average loss: 0.0
# episode: 8   score: 0.0   memory length: 1425   epsilon: 1.0   global_step: 1425   average_q: 0.06421084527288919   average loss: 0.0
# episode: 9   score: 0.0   memory length: 1556   epsilon: 1.0   global_step: 1556   average_q: 0.06416550034102593   average loss: 0.0
# episode: 10   score: 1.0   memory length: 1693   epsilon: 1.0   global_step: 1693   average_q: 0.06209934260832132   average loss: 0.0
# episode: 11   score: 3.0   memory length: 1924   epsilon: 1.0   global_step: 1924   average_q: 0.060517025232573095   average loss: 0.0
# episode: 12   score: 2.0   memory length: 2112   epsilon: 1.0   global_step: 2112   average_q: 0.06253873753024543   average loss: 0.0
# episode: 13   score: 3.0   memory length: 2332   epsilon: 1.0   global_step: 2332   average_q: 0.06242224055935036   average loss: 0.0
# episode: 14   score: 2.0   memory length: 2559   epsilon: 1.0   global_step: 2559   average_q: 0.06363418107515915   average loss: 0.0
# episode: 15   score: 1.0   memory length: 2720   epsilon: 1.0   global_step: 2720   average_q: 0.0616052258551491   average loss: 0.0
# episode: 16   score: 2.0   memory length: 2921   epsilon: 1.0   global_step: 2921   average_q: 0.062472628253461115   average loss: 0.0
# episode: 17   score: 0.0   memory length: 3052   epsilon: 1.0   global_step: 3052   average_q: 0.06447621099366486   average loss: 0.0
# episode: 18   score: 1.0   memory length: 3206   epsilon: 1.0   global_step: 3206   average_q: 0.060968577015129005   average loss: 0.0
# episode: 19   score: 0.0   memory length: 3337   epsilon: 1.0   global_step: 3337   average_q: 0.06412752993575489   average loss: 0.0
# episode: 20   score: 1.0   memory length: 3506   epsilon: 1.0   global_step: 3506   average_q: 0.061961417874464624   average loss: 0.0
# episode: 21   score: 2.0   memory length: 3699   epsilon: 1.0   global_step: 3699   average_q: 0.061653622594985316   average loss: 0.0
# episode: 22   score: 3.0   memory length: 3936   epsilon: 1.0   global_step: 3936   average_q: 0.06165327185191183   average loss: 0.0
# episode: 23   score: 2.0   memory length: 4127   epsilon: 1.0   global_step: 4127   average_q: 0.06315998970994151   average loss: 0.0
# episode: 24   score: 1.0   memory length: 4256   epsilon: 1.0   global_step: 4256   average_q: 0.061898263849953346   average loss: 0.0
# episode: 25   score: 1.0   memory length: 4396   epsilon: 1.0   global_step: 4396   average_q: 0.0643981025953378   average loss: 0.0
# episode: 26   score: 2.0   memory length: 4588   epsilon: 1.0   global_step: 4588   average_q: 0.0618632691524302   average loss: 0.0
# episode: 27   score: 1.0   memory length: 4755   epsilon: 1.0   global_step: 4755   average_q: 0.06386768199994179   average loss: 0.0
# episode: 28   score: 0.0   memory length: 4859   epsilon: 1.0   global_step: 4859   average_q: 0.06392621198812357   average loss: 0.0
# episode: 29   score: 2.0   memory length: 5053   epsilon: 1.0   global_step: 5053   average_q: 0.06309536087912382   average loss: 0.0
# episode: 30   score: 0.0   memory length: 5177   epsilon: 1.0   global_step: 5177   average_q: 0.06412143428479472   average loss: 0.0
# episode: 31   score: 1.0   memory length: 5332   epsilon: 1.0   global_step: 5332   average_q: 0.06202259712642239   average loss: 0.0
# episode: 32   score: 0.0   memory length: 5462   epsilon: 1.0   global_step: 5462   average_q: 0.06362646262233074   average loss: 0.0
# episode: 33   score: 0.0   memory length: 5584   epsilon: 1.0   global_step: 5584   average_q: 0.06427524357911993   average loss: 0.0
# episode: 34   score: 2.0   memory length: 5778   epsilon: 1.0   global_step: 5778   average_q: 0.0623231605271396   average loss: 0.0
# episode: 35   score: 1.0   memory length: 5924   epsilon: 1.0   global_step: 5924   average_q: 0.06319037184425413   average loss: 0.0
# episode: 36   score: 2.0   memory length: 6104   epsilon: 1.0   global_step: 6104   average_q: 0.06352984743813674   average loss: 0.0
# episode: 37   score: 0.0   memory length: 6212   epsilon: 1.0   global_step: 6212   average_q: 0.06425426710672953   average loss: 0.0
# episode: 38   score: 2.0   memory length: 6389   epsilon: 1.0   global_step: 6389   average_q: 0.0631915538408662   average loss: 0.0
# episode: 39   score: 0.0   memory length: 6511   epsilon: 1.0   global_step: 6511   average_q: 0.06376929443757065   average loss: 0.0
# episode: 40   score: 4.0   memory length: 6810   epsilon: 1.0   global_step: 6810   average_q: 0.06742209468946408   average loss: 0.0
# episode: 41   score: 1.0   memory length: 6979   epsilon: 1.0   global_step: 6979   average_q: 0.062188821166930114   average loss: 0.0
# episode: 42   score: 0.0   memory length: 7096   epsilon: 1.0   global_step: 7096   average_q: 0.0639586657540411   average loss: 0.0
# episode: 43   score: 1.0   memory length: 7259   epsilon: 1.0   global_step: 7259   average_q: 0.06334037866237704   average loss: 0.0
# episode: 44   score: 0.0   memory length: 7374   epsilon: 1.0   global_step: 7374   average_q: 0.06435167617771936   average loss: 0.0
# episode: 45   score: 0.0   memory length: 7490   epsilon: 1.0   global_step: 7490   average_q: 0.0645198292131054   average loss: 0.0
# episode: 46   score: 2.0   memory length: 7646   epsilon: 1.0   global_step: 7646   average_q: 0.06298704925351419   average loss: 0.0
# episode: 47   score: 1.0   memory length: 7794   epsilon: 1.0   global_step: 7794   average_q: 0.06152120212445388   average loss: 0.0
# episode: 48   score: 3.0   memory length: 8036   epsilon: 1.0   global_step: 8036   average_q: 0.06216947126302345   average loss: 0.0
# episode: 49   score: 0.0   memory length: 8146   epsilon: 1.0   global_step: 8146   average_q: 0.06392856277525424   average loss: 0.0
# episode: 50   score: 2.0   memory length: 8342   epsilon: 1.0   global_step: 8342   average_q: 0.06337472279461062   average loss: 0.0
# episode: 51   score: 0.0   memory length: 8468   epsilon: 1.0   global_step: 8468   average_q: 0.06377784074062393   average loss: 0.0
# episode: 52   score: 0.0   memory length: 8561   epsilon: 1.0   global_step: 8561   average_q: 0.06416918729902596   average loss: 0.0
# episode: 53   score: 0.0   memory length: 8682   epsilon: 1.0   global_step: 8682   average_q: 0.06444061387422656   average loss: 0.0
# episode: 54   score: 4.0   memory length: 8992   epsilon: 1.0   global_step: 8992   average_q: 0.06808652673517504   average loss: 0.0
# episode: 55   score: 0.0   memory length: 9096   epsilon: 1.0   global_step: 9096   average_q: 0.06450257059903099   average loss: 0.0
# episode: 56   score: 2.0   memory length: 9282   epsilon: 1.0   global_step: 9282   average_q: 0.06367536393865462   average loss: 0.0
# episode: 57   score: 0.0   memory length: 9416   epsilon: 1.0   global_step: 9416   average_q: 0.06390057226170355   average loss: 0.0
# episode: 58   score: 0.0   memory length: 9551   epsilon: 1.0   global_step: 9551   average_q: 0.06336644951392104   average loss: 0.0
# episode: 59   score: 3.0   memory length: 9777   epsilon: 1.0   global_step: 9777   average_q: 0.06299855192480362   average loss: 0.0
# episode: 60   score: 0.0   memory length: 9884   epsilon: 1.0   global_step: 9884   average_q: 0.06412380867611582   average loss: 0.0
# episode: 61   score: 2.0   memory length: 10063   epsilon: 1.0   global_step: 10063   average_q: 0.06224365178599704   average loss: 0.0
# episode: 62   score: 1.0   memory length: 10212   epsilon: 1.0   global_step: 10212   average_q: 0.06159651011928616   average loss: 0.0
# episode: 63   score: 4.0   memory length: 10469   epsilon: 1.0   global_step: 10469   average_q: 0.06384091364792349   average loss: 0.0
# episode: 64   score: 2.0   memory length: 10649   epsilon: 1.0   global_step: 10649   average_q: 0.06304176538768742   average loss: 0.0
# episode: 65   score: 1.0   memory length: 10805   epsilon: 1.0   global_step: 10805   average_q: 0.061739394321846656   average loss: 0.0
# episode: 66   score: 0.0   memory length: 10905   epsilon: 1.0   global_step: 10905   average_q: 0.06424182444810868   average loss: 0.0
# episode: 67   score: 3.0   memory length: 11134   epsilon: 1.0   global_step: 11134   average_q: 0.06511348012558238   average loss: 0.0
# episode: 68   score: 1.0   memory length: 11315   epsilon: 1.0   global_step: 11315   average_q: 0.062002207075364024   average loss: 0.0
# episode: 69   score: 0.0   memory length: 11439   epsilon: 1.0   global_step: 11439   average_q: 0.06472348067308625   average loss: 0.0
# episode: 70   score: 0.0   memory length: 11539   epsilon: 1.0   global_step: 11539   average_q: 0.06461316991597414   average loss: 0.0
# episode: 71   score: 2.0   memory length: 11746   epsilon: 1.0   global_step: 11746   average_q: 0.0612956585659497   average loss: 0.0
# episode: 72   score: 0.0   memory length: 11858   epsilon: 1.0   global_step: 11858   average_q: 0.06490518319021378   average loss: 0.0
# episode: 73   score: 0.0   memory length: 11981   epsilon: 1.0   global_step: 11981   average_q: 0.06382928231382758   average loss: 0.0
# episode: 74   score: 1.0   memory length: 12118   epsilon: 1.0   global_step: 12118   average_q: 0.06284484607133552   average loss: 0.0
# episode: 75   score: 0.0   memory length: 12235   epsilon: 1.0   global_step: 12235   average_q: 0.06426181055159651   average loss: 0.0
# episode: 76   score: 1.0   memory length: 12383   epsilon: 1.0   global_step: 12383   average_q: 0.061199711283316485   average loss: 0.0
# episode: 77   score: 2.0   memory length: 12604   epsilon: 1.0   global_step: 12604   average_q: 0.06407973557980352   average loss: 0.0
# episode: 78   score: 0.0   memory length: 12700   epsilon: 1.0   global_step: 12700   average_q: 0.06403359522422154   average loss: 0.0
# episode: 79   score: 2.0   memory length: 12877   epsilon: 1.0   global_step: 12877   average_q: 0.06254344439860117   average loss: 0.0
# episode: 80   score: 0.0   memory length: 12988   epsilon: 1.0   global_step: 12988   average_q: 0.06445103548131548   average loss: 0.0
# episode: 81   score: 1.0   memory length: 13157   epsilon: 1.0   global_step: 13157   average_q: 0.06279532293948902   average loss: 0.0
# episode: 82   score: 0.0   memory length: 13275   epsilon: 1.0   global_step: 13275   average_q: 0.06396368000719507   average loss: 0.0
# episode: 83   score: 2.0   memory length: 13483   epsilon: 1.0   global_step: 13483   average_q: 0.06340954796626018   average loss: 0.0
# episode: 84   score: 0.0   memory length: 13592   epsilon: 1.0   global_step: 13592   average_q: 0.06405715429044645   average loss: 0.0
# episode: 85   score: 1.0   memory length: 13725   epsilon: 1.0   global_step: 13725   average_q: 0.06150019222072193   average loss: 0.0
# episode: 86   score: 2.0   memory length: 13903   epsilon: 1.0   global_step: 13903   average_q: 0.0612742972633477   average loss: 0.0
# episode: 87   score: 4.0   memory length: 14195   epsilon: 1.0   global_step: 14195   average_q: 0.06636982813018234   average loss: 0.0
# episode: 88   score: 0.0   memory length: 14305   epsilon: 1.0   global_step: 14305   average_q: 0.0635549896820025   average loss: 0.0
# episode: 89   score: 0.0   memory length: 14423   epsilon: 1.0   global_step: 14423   average_q: 0.06427939135139271   average loss: 0.0
# episode: 90   score: 1.0   memory length: 14593   epsilon: 1.0   global_step: 14593   average_q: 0.0616733898573062   average loss: 0.0
# episode: 91   score: 4.0   memory length: 14859   epsilon: 1.0   global_step: 14859   average_q: 0.06440781989604011   average loss: 0.0
# episode: 92   score: 1.0   memory length: 15021   epsilon: 1.0   global_step: 15021   average_q: 0.06159724582584552   average loss: 0.0
# episode: 93   score: 0.0   memory length: 15133   epsilon: 1.0   global_step: 15133   average_q: 0.06441075624232846   average loss: 0.0
# episode: 94   score: 2.0   memory length: 15332   epsilon: 1.0   global_step: 15332   average_q: 0.06292482224016932   average loss: 0.0
# episode: 95   score: 2.0   memory length: 15516   epsilon: 1.0   global_step: 15516   average_q: 0.06276808500937793   average loss: 0.0
# episode: 96   score: 2.0   memory length: 15702   epsilon: 1.0   global_step: 15702   average_q: 0.06283303288122018   average loss: 0.0
# episode: 97   score: 1.0   memory length: 15848   epsilon: 1.0   global_step: 15848   average_q: 0.06333244882830202   average loss: 0.0
# episode: 98   score: 5.0   memory length: 16160   epsilon: 1.0   global_step: 16160   average_q: 0.0672382974686722   average loss: 0.0
# episode: 99   score: 3.0   memory length: 16410   epsilon: 1.0   global_step: 16410   average_q: 0.06274005126953125   average loss: 0.0
# episode: 100   score: 1.0   memory length: 16549   epsilon: 1.0   global_step: 16549   average_q: 0.06267601581250164   average loss: 0.0
# episode: 101   score: 0.0   memory length: 16684   epsilon: 1.0   global_step: 16684   average_q: 0.06448526506622633   average loss: 0.0
# episode: 102   score: 0.0   memory length: 16785   epsilon: 1.0   global_step: 16785   average_q: 0.06480809360152424   average loss: 0.0
# episode: 103   score: 1.0   memory length: 16910   epsilon: 1.0   global_step: 16910   average_q: 0.06399995374679565   average loss: 0.0
# episode: 104   score: 2.0   memory length: 17105   epsilon: 1.0   global_step: 17105   average_q: 0.06244406155668772   average loss: 0.0
# episode: 105   score: 0.0   memory length: 17203   epsilon: 1.0   global_step: 17203   average_q: 0.06514241496975325   average loss: 0.0
# episode: 106   score: 1.0   memory length: 17342   epsilon: 1.0   global_step: 17342   average_q: 0.06461818398331566   average loss: 0.0
# episode: 107   score: 0.0   memory length: 17467   epsilon: 1.0   global_step: 17467   average_q: 0.06390809416770935   average loss: 0.0
# episode: 108   score: 1.0   memory length: 17608   epsilon: 1.0   global_step: 17608   average_q: 0.064225860468462   average loss: 0.0
# episode: 109   score: 1.0   memory length: 17774   epsilon: 1.0   global_step: 17774   average_q: 0.06324888545885143   average loss: 0.0
# episode: 110   score: 5.0   memory length: 18108   epsilon: 1.0   global_step: 18108   average_q: 0.06444594741402986   average loss: 0.0
# episode: 111   score: 0.0   memory length: 18237   epsilon: 1.0   global_step: 18237   average_q: 0.06403812615908394   average loss: 0.0
# episode: 112   score: 1.0   memory length: 18375   epsilon: 1.0   global_step: 18375   average_q: 0.06308666246848693   average loss: 0.0
# episode: 113   score: 0.0   memory length: 18503   epsilon: 1.0   global_step: 18503   average_q: 0.06477487747906707   average loss: 0.0
# episode: 114   score: 1.0   memory length: 18662   epsilon: 1.0   global_step: 18662   average_q: 0.06291837641184435   average loss: 0.0
# episode: 115   score: 0.0   memory length: 18793   epsilon: 1.0   global_step: 18793   average_q: 0.0640090542440196   average loss: 0.0
# episode: 116   score: 1.0   memory length: 18959   epsilon: 1.0   global_step: 18959   average_q: 0.061764056648475577   average loss: 0.0
# episode: 117   score: 2.0   memory length: 19165   epsilon: 1.0   global_step: 19165   average_q: 0.0640293982567139   average loss: 0.0
# episode: 118   score: 3.0   memory length: 19388   epsilon: 1.0   global_step: 19388   average_q: 0.06310684359193917   average loss: 0.0
# episode: 119   score: 2.0   memory length: 19574   epsilon: 1.0   global_step: 19574   average_q: 0.061570930785389354   average loss: 0.0
# episode: 120   score: 3.0   memory length: 19792   epsilon: 1.0   global_step: 19792   average_q: 0.063367095801535   average loss: 0.0
# episode: 121   score: 1.0   memory length: 19948   epsilon: 1.0   global_step: 19948   average_q: 0.06411499601717179   average loss: 0.0
# episode: 122   score: 0.0   memory length: 20078   epsilon: 1.0   global_step: 20078   average_q: 0.0641700386427916   average loss: 0.0
# episode: 123   score: 1.0   memory length: 20236   epsilon: 1.0   global_step: 20236   average_q: 0.06289297627591633   average loss: 0.0
# episode: 124   score: 0.0   memory length: 20350   epsilon: 1.0   global_step: 20350   average_q: 0.06403641517094352   average loss: 0.0
# episode: 125   score: 1.0   memory length: 20484   epsilon: 1.0   global_step: 20484   average_q: 0.06315211670945829   average loss: 0.0
# episode: 126   score: 2.0   memory length: 20697   epsilon: 1.0   global_step: 20697   average_q: 0.06175635006506119   average loss: 0.0
# episode: 127   score: 0.0   memory length: 20803   epsilon: 1.0   global_step: 20803   average_q: 0.06412202295548511   average loss: 0.0
# episode: 128   score: 3.0   memory length: 21063   epsilon: 1.0   global_step: 21063   average_q: 0.06260233809455083   average loss: 0.0
# episode: 129   score: 3.0   memory length: 21310   epsilon: 1.0   global_step: 21310   average_q: 0.06452397783456544   average loss: 0.0
# episode: 130   score: 2.0   memory length: 21475   epsilon: 1.0   global_step: 21475   average_q: 0.06230183006687598   average loss: 0.0
# episode: 131   score: 1.0   memory length: 21600   epsilon: 1.0   global_step: 21600   average_q: 0.06302918142080308   average loss: 0.0
# episode: 132   score: 1.0   memory length: 21753   epsilon: 1.0   global_step: 21753   average_q: 0.062172320835730606   average loss: 0.0
# episode: 133   score: 0.0   memory length: 21881   epsilon: 1.0   global_step: 21881   average_q: 0.06407720706192777   average loss: 0.0
# episode: 134   score: 2.0   memory length: 22091   epsilon: 1.0   global_step: 22091   average_q: 0.06245501165588697   average loss: 0.0
# episode: 135   score: 1.0   memory length: 22256   epsilon: 1.0   global_step: 22256   average_q: 0.06233629620436466   average loss: 0.0
# episode: 136   score: 2.0   memory length: 22441   epsilon: 1.0   global_step: 22441   average_q: 0.06311295507727442   average loss: 0.0
# episode: 137   score: 2.0   memory length: 22650   epsilon: 1.0   global_step: 22650   average_q: 0.06195429126112655   average loss: 0.0
# episode: 138   score: 1.0   memory length: 22794   epsilon: 1.0   global_step: 22794   average_q: 0.061405597642684974   average loss: 0.0
# episode: 139   score: 0.0   memory length: 22896   epsilon: 1.0   global_step: 22896   average_q: 0.06419608391383115   average loss: 0.0
# episode: 140   score: 0.0   memory length: 23010   epsilon: 1.0   global_step: 23010   average_q: 0.06401854603175532   average loss: 0.0
# episode: 141   score: 0.0   memory length: 23138   epsilon: 1.0   global_step: 23138   average_q: 0.06448296425514854   average loss: 0.0
# episode: 142   score: 0.0   memory length: 23236   epsilon: 1.0   global_step: 23236   average_q: 0.06452343647121167   average loss: 0.0
# episode: 143   score: 1.0   memory length: 23391   epsilon: 1.0   global_step: 23391   average_q: 0.06213708962163617   average loss: 0.0
# episode: 144   score: 0.0   memory length: 23507   epsilon: 1.0   global_step: 23507   average_q: 0.0644417516887188   average loss: 0.0
# episode: 145   score: 1.0   memory length: 23683   epsilon: 1.0   global_step: 23683   average_q: 0.06130842902612957   average loss: 0.0
# episode: 146   score: 0.0   memory length: 23787   epsilon: 1.0   global_step: 23787   average_q: 0.06476924382150173   average loss: 0.0
# episode: 147   score: 2.0   memory length: 23989   epsilon: 1.0   global_step: 23989   average_q: 0.06409946699986363   average loss: 0.0
# episode: 148   score: 1.0   memory length: 24146   epsilon: 1.0   global_step: 24146   average_q: 0.06271219841993539   average loss: 0.0
# episode: 149   score: 1.0   memory length: 24303   epsilon: 1.0   global_step: 24303   average_q: 0.06131559403933537   average loss: 0.0
# episode: 150   score: 0.0   memory length: 24421   epsilon: 1.0   global_step: 24421   average_q: 0.06435897924258548   average loss: 0.0
# episode: 151   score: 0.0   memory length: 24524   epsilon: 1.0   global_step: 24524   average_q: 0.06468095879965616   average loss: 0.0
# episode: 152   score: 0.0   memory length: 24640   epsilon: 1.0   global_step: 24640   average_q: 0.06456805939047501   average loss: 0.0
# episode: 153   score: 0.0   memory length: 24752   epsilon: 1.0   global_step: 24752   average_q: 0.06386943700324212   average loss: 0.0
# episode: 154   score: 1.0   memory length: 24908   epsilon: 1.0   global_step: 24908   average_q: 0.06414577768494685   average loss: 0.0
# episode: 155   score: 1.0   memory length: 25049   epsilon: 1.0   global_step: 25049   average_q: 0.0614252157297963   average loss: 0.0
# episode: 156   score: 0.0   memory length: 25148   epsilon: 1.0   global_step: 25148   average_q: 0.06494513996923813   average loss: 0.0
# episode: 157   score: 4.0   memory length: 25424   epsilon: 1.0   global_step: 25424   average_q: 0.06324178158589032   average loss: 0.0
# episode: 158   score: 3.0   memory length: 25651   epsilon: 1.0   global_step: 25651   average_q: 0.0630110829149574   average loss: 0.0
# episode: 159   score: 0.0   memory length: 25767   epsilon: 1.0   global_step: 25767   average_q: 0.06444129871268725   average loss: 0.0
# episode: 160   score: 2.0   memory length: 25948   epsilon: 1.0   global_step: 25948   average_q: 0.06111332204048805   average loss: 0.0
# episode: 161   score: 0.0   memory length: 26067   epsilon: 1.0   global_step: 26067   average_q: 0.06373764821836929   average loss: 0.0
# episode: 162   score: 3.0   memory length: 26300   epsilon: 1.0   global_step: 26300   average_q: 0.06336926318737059   average loss: 0.0
# episode: 163   score: 2.0   memory length: 26481   epsilon: 1.0   global_step: 26481   average_q: 0.06177779682268754   average loss: 0.0
# episode: 164   score: 2.0   memory length: 26687   epsilon: 1.0   global_step: 26687   average_q: 0.06366864293452026   average loss: 0.0
# episode: 165   score: 1.0   memory length: 26842   epsilon: 1.0   global_step: 26842   average_q: 0.06335730463747055   average loss: 0.0
# episode: 166   score: 0.0   memory length: 26965   epsilon: 1.0   global_step: 26965   average_q: 0.06441292630099668   average loss: 0.0
# episode: 167   score: 1.0   memory length: 27131   epsilon: 1.0   global_step: 27131   average_q: 0.0632060123944139   average loss: 0.0
# episode: 168   score: 0.0   memory length: 27254   epsilon: 1.0   global_step: 27254   average_q: 0.0647383231094213   average loss: 0.0
# episode: 169   score: 0.0   memory length: 27372   epsilon: 1.0   global_step: 27372   average_q: 0.06394175316949012   average loss: 0.0
# episode: 170   score: 1.0   memory length: 27534   epsilon: 1.0   global_step: 27534   average_q: 0.062081005677212905   average loss: 0.0
# episode: 171   score: 2.0   memory length: 27725   epsilon: 1.0   global_step: 27725   average_q: 0.06362772793435925   average loss: 0.0
# episode: 172   score: 2.0   memory length: 27922   epsilon: 1.0   global_step: 27922   average_q: 0.061738992327360936   average loss: 0.0
# episode: 173   score: 2.0   memory length: 28114   epsilon: 1.0   global_step: 28114   average_q: 0.06269091138771425   average loss: 0.0
# episode: 174   score: 2.0   memory length: 28323   epsilon: 1.0   global_step: 28323   average_q: 0.06255716206639578   average loss: 0.0
# episode: 175   score: 2.0   memory length: 28518   epsilon: 1.0   global_step: 28518   average_q: 0.06124263247236227   average loss: 0.0
# episode: 176   score: 0.0   memory length: 28615   epsilon: 1.0   global_step: 28615   average_q: 0.06447990330838665   average loss: 0.0
# episode: 177   score: 2.0   memory length: 28831   epsilon: 1.0   global_step: 28831   average_q: 0.06198014163722595   average loss: 0.0
# episode: 178   score: 4.0   memory length: 29126   epsilon: 1.0   global_step: 29126   average_q: 0.06376012900875787   average loss: 0.0
# episode: 179   score: 0.0   memory length: 29237   epsilon: 1.0   global_step: 29237   average_q: 0.0644585787578746   average loss: 0.0
# episode: 180   score: 1.0   memory length: 29389   epsilon: 1.0   global_step: 29389   average_q: 0.061234852985331885   average loss: 0.0
# episode: 181   score: 5.0   memory length: 29693   epsilon: 1.0   global_step: 29693   average_q: 0.06613320808269475   average loss: 0.0
# episode: 182   score: 0.0   memory length: 29816   epsilon: 1.0   global_step: 29816   average_q: 0.06423224245266217   average loss: 0.0
# episode: 183   score: 0.0   memory length: 29921   epsilon: 1.0   global_step: 29921   average_q: 0.06468566464526312   average loss: 0.0
# episode: 184   score: 0.0   memory length: 30030   epsilon: 1.0   global_step: 30030   average_q: 0.06427826154806199   average loss: 0.0
# episode: 185   score: 0.0   memory length: 30149   epsilon: 1.0   global_step: 30149   average_q: 0.06418617789735313   average loss: 0.0
# episode: 186   score: 0.0   memory length: 30252   epsilon: 1.0   global_step: 30252   average_q: 0.06437162519658654   average loss: 0.0
# episode: 187   score: 0.0   memory length: 30373   epsilon: 1.0   global_step: 30373   average_q: 0.06414400958571552   average loss: 0.0
# episode: 188   score: 2.0   memory length: 30586   epsilon: 1.0   global_step: 30586   average_q: 0.06269187704078469   average loss: 0.0
# episode: 189   score: 0.0   memory length: 30707   epsilon: 1.0   global_step: 30707   average_q: 0.06413858503965307   average loss: 0.0
# episode: 190   score: 0.0   memory length: 30818   epsilon: 1.0   global_step: 30818   average_q: 0.06412627484213125   average loss: 0.0
# episode: 191   score: 0.0   memory length: 30915   epsilon: 1.0   global_step: 30915   average_q: 0.06464561962128915   average loss: 0.0
# episode: 192   score: 0.0   memory length: 31027   epsilon: 1.0   global_step: 31027   average_q: 0.06389256636612117   average loss: 0.0
# episode: 193   score: 0.0   memory length: 31153   epsilon: 1.0   global_step: 31153   average_q: 0.06488420202263764   average loss: 0.0
# episode: 194   score: 1.0   memory length: 31326   epsilon: 1.0   global_step: 31326   average_q: 0.062310747952991824   average loss: 0.0
# episode: 195   score: 3.0   memory length: 31573   epsilon: 1.0   global_step: 31573   average_q: 0.06405931196895688   average loss: 0.0
# episode: 196   score: 2.0   memory length: 31772   epsilon: 1.0   global_step: 31772   average_q: 0.0630950258866926   average loss: 0.0
# episode: 197   score: 3.0   memory length: 31970   epsilon: 1.0   global_step: 31970   average_q: 0.06228729881195709   average loss: 0.0
# episode: 198   score: 0.0   memory length: 32070   epsilon: 1.0   global_step: 32070   average_q: 0.06451121255755425   average loss: 0.0
# episode: 199   score: 0.0   memory length: 32207   epsilon: 1.0   global_step: 32207   average_q: 0.06402432184367285   average loss: 0.0
# episode: 200   score: 1.0   memory length: 32366   epsilon: 1.0   global_step: 32366   average_q: 0.06201830585985064   average loss: 0.0
# episode: 201   score: 1.0   memory length: 32519   epsilon: 1.0   global_step: 32519   average_q: 0.06410366306507509   average loss: 0.0
# episode: 202   score: 0.0   memory length: 32630   epsilon: 1.0   global_step: 32630   average_q: 0.06462346510709943   average loss: 0.0
# episode: 203   score: 1.0   memory length: 32759   epsilon: 1.0   global_step: 32759   average_q: 0.06427975050931753   average loss: 0.0
# episode: 204   score: 2.0   memory length: 32954   epsilon: 1.0   global_step: 32954   average_q: 0.0623175581296285   average loss: 0.0
# episode: 205   score: 2.0   memory length: 33123   epsilon: 1.0   global_step: 33123   average_q: 0.06304321367536071   average loss: 0.0
# episode: 206   score: 2.0   memory length: 33310   epsilon: 1.0   global_step: 33310   average_q: 0.061280659972665144   average loss: 0.0
# episode: 207   score: 2.0   memory length: 33505   epsilon: 1.0   global_step: 33505   average_q: 0.061805413758907565   average loss: 0.0
# episode: 208   score: 0.0   memory length: 33624   epsilon: 1.0   global_step: 33624   average_q: 0.0641089283994266   average loss: 0.0
# episode: 209   score: 2.0   memory length: 33785   epsilon: 1.0   global_step: 33785   average_q: 0.0635194713423341   average loss: 0.0
# episode: 210   score: 1.0   memory length: 33930   epsilon: 1.0   global_step: 33930   average_q: 0.0632840354637853   average loss: 0.0
# episode: 211   score: 2.0   memory length: 34121   epsilon: 1.0   global_step: 34121   average_q: 0.06250067687159433   average loss: 0.0
# episode: 212   score: 0.0   memory length: 34239   epsilon: 1.0   global_step: 34239   average_q: 0.06450043580794738   average loss: 0.0
# episode: 213   score: 1.0   memory length: 34402   epsilon: 1.0   global_step: 34402   average_q: 0.06362556709559417   average loss: 0.0
# episode: 214   score: 0.0   memory length: 34522   epsilon: 1.0   global_step: 34522   average_q: 0.06313144999245802   average loss: 0.0
# episode: 215   score: 0.0   memory length: 34648   epsilon: 1.0   global_step: 34648   average_q: 0.06386697626421375   average loss: 0.0
# episode: 216   score: 0.0   memory length: 34775   epsilon: 1.0   global_step: 34775   average_q: 0.0643080797075756   average loss: 0.0
# episode: 217   score: 1.0   memory length: 34910   epsilon: 1.0   global_step: 34910   average_q: 0.06198611816874257   average loss: 0.0
# episode: 218   score: 2.0   memory length: 35107   epsilon: 1.0   global_step: 35107   average_q: 0.06325585911343545   average loss: 0.0
# episode: 219   score: 1.0   memory length: 35260   epsilon: 1.0   global_step: 35260   average_q: 0.06149250651204508   average loss: 0.0
# episode: 220   score: 3.0   memory length: 35474   epsilon: 1.0   global_step: 35474   average_q: 0.06062263581101025   average loss: 0.0
# episode: 221   score: 0.0   memory length: 35579   epsilon: 1.0   global_step: 35579   average_q: 0.06432056451837222   average loss: 0.0
# episode: 222   score: 1.0   memory length: 35755   epsilon: 1.0   global_step: 35755   average_q: 0.0630195491566238   average loss: 0.0
# episode: 223   score: 0.0   memory length: 35878   epsilon: 1.0   global_step: 35878   average_q: 0.06418081009533347   average loss: 0.0
# episode: 224   score: 0.0   memory length: 35974   epsilon: 1.0   global_step: 35974   average_q: 0.06465037729746352   average loss: 0.0
# episode: 225   score: 1.0   memory length: 36098   epsilon: 1.0   global_step: 36098   average_q: 0.06292880332518008   average loss: 0.0
# episode: 226   score: 0.0   memory length: 36219   epsilon: 1.0   global_step: 36219   average_q: 0.0645749257369475   average loss: 0.0
# episode: 227   score: 0.0   memory length: 36336   epsilon: 1.0   global_step: 36336   average_q: 0.06442330847693305   average loss: 0.0
# episode: 228   score: 0.0   memory length: 36437   epsilon: 1.0   global_step: 36437   average_q: 0.06451428312771391   average loss: 0.0
# episode: 229   score: 3.0   memory length: 36704   epsilon: 1.0   global_step: 36704   average_q: 0.06198320138766971   average loss: 0.0
# episode: 230   score: 0.0   memory length: 36828   epsilon: 1.0   global_step: 36828   average_q: 0.0640954251791681   average loss: 0.0
# episode: 231   score: 1.0   memory length: 36956   epsilon: 1.0   global_step: 36956   average_q: 0.0645748405077029   average loss: 0.0
# episode: 232   score: 1.0   memory length: 37113   epsilon: 1.0   global_step: 37113   average_q: 0.06114360780283144   average loss: 0.0
# episode: 233   score: 1.0   memory length: 37265   epsilon: 1.0   global_step: 37265   average_q: 0.061535166453962266   average loss: 0.0
# episode: 234   score: 2.0   memory length: 37457   epsilon: 1.0   global_step: 37457   average_q: 0.06307486454412962   average loss: 0.0
# episode: 235   score: 1.0   memory length: 37622   epsilon: 1.0   global_step: 37622   average_q: 0.06099994105823112   average loss: 0.0
# episode: 236   score: 1.0   memory length: 37770   epsilon: 1.0   global_step: 37770   average_q: 0.06338048766593675   average loss: 0.0
# episode: 237   score: 2.0   memory length: 37962   epsilon: 1.0   global_step: 37962   average_q: 0.06178275850834325   average loss: 0.0
# episode: 238   score: 1.0   memory length: 38129   epsilon: 1.0   global_step: 38129   average_q: 0.062331370429364506   average loss: 0.0
# episode: 239   score: 3.0   memory length: 38340   epsilon: 1.0   global_step: 38340   average_q: 0.06202372832673986   average loss: 0.0
# episode: 240   score: 1.0   memory length: 38496   epsilon: 1.0   global_step: 38496   average_q: 0.06445222307378665   average loss: 0.0
# episode: 241   score: 2.0   memory length: 38699   epsilon: 1.0   global_step: 38699   average_q: 0.061778295253004344   average loss: 0.0
# episode: 242   score: 0.0   memory length: 38803   epsilon: 1.0   global_step: 38803   average_q: 0.06416657169421132   average loss: 0.0
# episode: 243   score: 1.0   memory length: 38968   epsilon: 1.0   global_step: 38968   average_q: 0.06365740109573712   average loss: 0.0
# episode: 244   score: 2.0   memory length: 39158   epsilon: 1.0   global_step: 39158   average_q: 0.06201928655960058   average loss: 0.0
# episode: 245   score: 2.0   memory length: 39349   epsilon: 1.0   global_step: 39349   average_q: 0.06331630698673388   average loss: 0.0
# episode: 246   score: 1.0   memory length: 39500   epsilon: 1.0   global_step: 39500   average_q: 0.06207840339533541   average loss: 0.0
# episode: 247   score: 1.0   memory length: 39669   epsilon: 1.0   global_step: 39669   average_q: 0.06402825672157417   average loss: 0.0
# episode: 248   score: 0.0   memory length: 39801   epsilon: 1.0   global_step: 39801   average_q: 0.06391802636172736   average loss: 0.0
# episode: 249   score: 0.0   memory length: 39904   epsilon: 1.0   global_step: 39904   average_q: 0.06473860075896226   average loss: 0.0
# episode: 250   score: 1.0   memory length: 40048   epsilon: 1.0   global_step: 40048   average_q: 0.06145792309608725   average loss: 0.0
# episode: 251   score: 3.0   memory length: 40294   epsilon: 1.0   global_step: 40294   average_q: 0.06321071513845183   average loss: 0.0
# episode: 252   score: 1.0   memory length: 40434   epsilon: 1.0   global_step: 40434   average_q: 0.06451456807553768   average loss: 0.0
# episode: 253   score: 1.0   memory length: 40557   epsilon: 1.0   global_step: 40557   average_q: 0.061931293245738116   average loss: 0.0
# episode: 254   score: 2.0   memory length: 40751   epsilon: 1.0   global_step: 40751   average_q: 0.061417946227125285   average loss: 0.0
# episode: 255   score: 0.0   memory length: 40884   epsilon: 1.0   global_step: 40884   average_q: 0.06409831524343419   average loss: 0.0
# episode: 256   score: 2.0   memory length: 41092   epsilon: 1.0   global_step: 41092   average_q: 0.06277654989837454   average loss: 0.0
# episode: 257   score: 0.0   memory length: 41218   epsilon: 1.0   global_step: 41218   average_q: 0.06356993619175184   average loss: 0.0
# episode: 258   score: 3.0   memory length: 41468   epsilon: 1.0   global_step: 41468   average_q: 0.06359665702283382   average loss: 0.0
# episode: 259   score: 2.0   memory length: 41671   epsilon: 1.0   global_step: 41671   average_q: 0.06242554100790047   average loss: 0.0
# episode: 260   score: 0.0   memory length: 41781   epsilon: 1.0   global_step: 41781   average_q: 0.06419116793708368   average loss: 0.0
# episode: 261   score: 0.0   memory length: 41884   epsilon: 1.0   global_step: 41884   average_q: 0.06481838996693925   average loss: 0.0
# episode: 262   score: 0.0   memory length: 41997   epsilon: 1.0   global_step: 41997   average_q: 0.06444438893051274   average loss: 0.0
# episode: 263   score: 5.0   memory length: 42333   epsilon: 1.0   global_step: 42333   average_q: 0.06464594277730655   average loss: 0.0
# episode: 264   score: 0.0   memory length: 42438   epsilon: 1.0   global_step: 42438   average_q: 0.06453557727592332   average loss: 0.0
# episode: 265   score: 1.0   memory length: 42583   epsilon: 1.0   global_step: 42583   average_q: 0.06429423841423001   average loss: 0.0
# episode: 266   score: 0.0   memory length: 42710   epsilon: 1.0   global_step: 42710   average_q: 0.06369347530087148   average loss: 0.0
# episode: 267   score: 0.0   memory length: 42811   epsilon: 1.0   global_step: 42811   average_q: 0.06443523866410303   average loss: 0.0
# episode: 268   score: 3.0   memory length: 43059   epsilon: 1.0   global_step: 43059   average_q: 0.06540907386149611   average loss: 0.0
# episode: 269   score: 0.0   memory length: 43156   epsilon: 1.0   global_step: 43156   average_q: 0.06439377279164865   average loss: 0.0
# episode: 270   score: 2.0   memory length: 43345   epsilon: 1.0   global_step: 43345   average_q: 0.06303157495758521   average loss: 0.0
# episode: 271   score: 3.0   memory length: 43574   epsilon: 1.0   global_step: 43574   average_q: 0.06248463623583577   average loss: 0.0
# episode: 272   score: 2.0   memory length: 43747   epsilon: 1.0   global_step: 43747   average_q: 0.0616963173483493   average loss: 0.0
# episode: 273   score: 0.0   memory length: 43873   epsilon: 1.0   global_step: 43873   average_q: 0.06484748733540376   average loss: 0.0
# episode: 274   score: 2.0   memory length: 44040   epsilon: 1.0   global_step: 44040   average_q: 0.06035964195421356   average loss: 0.0
# episode: 275   score: 2.0   memory length: 44235   epsilon: 1.0   global_step: 44235   average_q: 0.06136876081044857   average loss: 0.0
# episode: 276   score: 1.0   memory length: 44380   epsilon: 1.0   global_step: 44380   average_q: 0.06308861559834973   average loss: 0.0
# episode: 277   score: 1.0   memory length: 44520   epsilon: 1.0   global_step: 44520   average_q: 0.061250092381877556   average loss: 0.0
# episode: 278   score: 0.0   memory length: 44645   epsilon: 1.0   global_step: 44645   average_q: 0.06391951909661293   average loss: 0.0
# episode: 279   score: 1.0   memory length: 44779   epsilon: 1.0   global_step: 44779   average_q: 0.06227829560303866   average loss: 0.0
# episode: 280   score: 1.0   memory length: 44949   epsilon: 1.0   global_step: 44949   average_q: 0.06417277674464618   average loss: 0.0
# episode: 281   score: 0.0   memory length: 45064   epsilon: 1.0   global_step: 45064   average_q: 0.06434286486195481   average loss: 0.0
# episode: 282   score: 0.0   memory length: 45176   epsilon: 1.0   global_step: 45176   average_q: 0.06370264930384499   average loss: 0.0
# episode: 283   score: 0.0   memory length: 45294   epsilon: 1.0   global_step: 45294   average_q: 0.0642904143906751   average loss: 0.0
# episode: 284   score: 2.0   memory length: 45505   epsilon: 1.0   global_step: 45505   average_q: 0.0627807860055241   average loss: 0.0
# episode: 285   score: 1.0   memory length: 45657   epsilon: 1.0   global_step: 45657   average_q: 0.06379516908016644   average loss: 0.0
# episode: 286   score: 0.0   memory length: 45772   epsilon: 1.0   global_step: 45772   average_q: 0.0638870201357033   average loss: 0.0
# episode: 287   score: 0.0   memory length: 45878   epsilon: 1.0   global_step: 45878   average_q: 0.06393024156678398   average loss: 0.0
# episode: 288   score: 1.0   memory length: 46051   epsilon: 1.0   global_step: 46051   average_q: 0.061243621837024746   average loss: 0.0
# episode: 289   score: 0.0   memory length: 46149   epsilon: 1.0   global_step: 46149   average_q: 0.06403900439641913   average loss: 0.0
# episode: 290   score: 1.0   memory length: 46311   epsilon: 1.0   global_step: 46311   average_q: 0.061358224807514086   average loss: 0.0
# episode: 291   score: 0.0   memory length: 46413   epsilon: 1.0   global_step: 46413   average_q: 0.06400099582970142   average loss: 0.0
# episode: 292   score: 1.0   memory length: 46548   epsilon: 1.0   global_step: 46548   average_q: 0.0626567926119875   average loss: 0.0
# episode: 293   score: 2.0   memory length: 46754   epsilon: 1.0   global_step: 46754   average_q: 0.062179940110705434   average loss: 0.0
# episode: 294   score: 2.0   memory length: 46949   epsilon: 1.0   global_step: 46949   average_q: 0.06435082678993544   average loss: 0.0
# episode: 295   score: 0.0   memory length: 47083   epsilon: 1.0   global_step: 47083   average_q: 0.06424705108711079   average loss: 0.0
# episode: 296   score: 1.0   memory length: 47230   epsilon: 1.0   global_step: 47230   average_q: 0.06412260913524498   average loss: 0.0
# episode: 297   score: 2.0   memory length: 47421   epsilon: 1.0   global_step: 47421   average_q: 0.06181440211793515   average loss: 0.0
# episode: 298   score: 1.0   memory length: 47596   epsilon: 1.0   global_step: 47596   average_q: 0.06218873475279127   average loss: 0.0
# episode: 299   score: 2.0   memory length: 47798   epsilon: 1.0   global_step: 47798   average_q: 0.06358438438855775   average loss: 0.0
# episode: 300   score: 0.0   memory length: 47920   epsilon: 1.0   global_step: 47920   average_q: 0.06425326677863716   average loss: 0.0
# episode: 301   score: 2.0   memory length: 48105   epsilon: 1.0   global_step: 48105   average_q: 0.06292428636067622   average loss: 0.0
# episode: 302   score: 0.0   memory length: 48226   epsilon: 1.0   global_step: 48226   average_q: 0.06420792349852807   average loss: 0.0
# episode: 303   score: 2.0   memory length: 48438   epsilon: 1.0   global_step: 48438   average_q: 0.06419243816426902   average loss: 0.0
# episode: 304   score: 0.0   memory length: 48539   epsilon: 1.0   global_step: 48539   average_q: 0.06396750146799748   average loss: 0.0
# episode: 305   score: 1.0   memory length: 48714   epsilon: 1.0   global_step: 48714   average_q: 0.06303303331136703   average loss: 0.0
# episode: 306   score: 0.0   memory length: 48846   epsilon: 1.0   global_step: 48846   average_q: 0.06394430986520919   average loss: 0.0
# episode: 307   score: 1.0   memory length: 48992   epsilon: 1.0   global_step: 48992   average_q: 0.06202059660157929   average loss: 0.0
# episode: 308   score: 0.0   memory length: 49089   epsilon: 1.0   global_step: 49089   average_q: 0.06426477267109242   average loss: 0.0
# episode: 309   score: 0.0   memory length: 49208   epsilon: 1.0   global_step: 49208   average_q: 0.06430553225409083   average loss: 0.0
# episode: 310   score: 3.0   memory length: 49428   epsilon: 1.0   global_step: 49428   average_q: 0.06271910767324947   average loss: 0.0
# episode: 311   score: 0.0   memory length: 49536   epsilon: 1.0   global_step: 49536   average_q: 0.06400446904202302   average loss: 0.0
# episode: 312   score: 1.0   memory length: 49686   epsilon: 1.0   global_step: 49686   average_q: 0.06333879359066487   average loss: 0.0
# episode: 313   score: 1.0   memory length: 49834   epsilon: 1.0   global_step: 49834   average_q: 0.06157712741578753   average loss: 0.0
# episode: 314   score: 0.0   memory length: 49958   epsilon: 1.0   global_step: 49958   average_q: 0.06430063117295504   average loss: 0.0
# episode: 315   score: 2.0   memory length: 50157   epsilon: 0.9998578000000047   global_step: 50157   average_q: 0.06936123823026318   average loss: 0.0032742283689328163
# episode: 316   score: 0.0   memory length: 50268   epsilon: 0.999757900000008   global_step: 50268   average_q: 0.06927442684903876   average loss: 0.0030342911776589463
# episode: 317   score: 0.0   memory length: 50366   epsilon: 0.9996697000000109   global_step: 50366   average_q: 0.07605960147873479   average loss: 0.004191137234046232
# episode: 318   score: 1.0   memory length: 50509   epsilon: 0.9995410000000151   global_step: 50509   average_q: 0.07126689043182594   average loss: 0.0032447269246703102
# episode: 319   score: 2.0   memory length: 50705   epsilon: 0.9993646000000209   global_step: 50705   average_q: 0.06934333780818448   average loss: 0.0028509742135434976
# episode: 320   score: 2.0   memory length: 50874   epsilon: 0.9992125000000259   global_step: 50874   average_q: 0.06974466552836656   average loss: 0.0030344960269763684
# episode: 321   score: 0.0   memory length: 50998   epsilon: 0.9991009000000296   global_step: 50998   average_q: 0.073615021973608   average loss: 0.0036975058069328363
# episode: 322   score: 1.0   memory length: 51174   epsilon: 0.9989425000000348   global_step: 51174   average_q: 0.07150176438418301   average loss: 0.003344110549968284
# episode: 323   score: 0.0   memory length: 51281   epsilon: 0.998846200000038   global_step: 51281   average_q: 0.07117203678761687   average loss: 0.0035680041210666064
# episode: 324   score: 2.0   memory length: 51478   epsilon: 0.9986689000000438   global_step: 51478   average_q: 0.06933311925170385   average loss: 0.002841193918636333
# ...
# episode: 2206   score: 1.0   memory length: 361737   epsilon: 0.7194358000092371   global_step: 361737   average_q: 0.17321392464818378   average loss: 0.0020769199620576037
# episode: 2207   score: 3.0   memory length: 361928   epsilon: 0.7192639000092428   global_step: 361928   average_q: 0.18891347156769317   average loss: 0.0023199412554986434
# episode: 2208   score: 2.0   memory length: 362153   epsilon: 0.7190614000092495   global_step: 362153   average_q: 0.29059029936790465   average loss: 0.0022288469447489154
# episode: 2209   score: 3.0   memory length: 362349   epsilon: 0.7188850000092553   global_step: 362349   average_q: 0.19166626781225204   average loss: 0.0027653698909526443
# episode: 2210   score: 3.0   memory length: 362563   epsilon: 0.7186924000092616   global_step: 362563   average_q: 0.22582474643381956   average loss: 0.0019376978834940851
# episode: 2211   score: 1.0   memory length: 362707   epsilon: 0.7185628000092659   global_step: 362707   average_q: 0.22505949065089226   average loss: 0.0021907191276113736
# episode: 2212   score: 1.0   memory length: 362866   epsilon: 0.7184197000092706   global_step: 362866   average_q: 0.17226579110577422   average loss: 0.002522141991485915
# episode: 2213   score: 1.0   memory length: 363009   epsilon: 0.7182910000092748   global_step: 363009   average_q: 0.19782977941986565   average loss: 0.0021442862775443786
# episode: 2214   score: 1.0   memory length: 363178   epsilon: 0.7181389000092798   global_step: 363178   average_q: 0.1461821572315058   average loss: 0.0028244495725850906
# episode: 2215   score: 0.0   memory length: 363294   epsilon: 0.7180345000092833   global_step: 363294   average_q: 0.12798213367832117   average loss: 0.00203483494091227
# episode: 2216   score: 4.0   memory length: 363591   epsilon: 0.7177672000092921   global_step: 363591   average_q: 0.24869861426176848   average loss: 0.002097319269780954
# episode: 2217   score: 3.0   memory length: 363807   epsilon: 0.7175728000092985   global_step: 363807   average_q: 0.19121544628783507   average loss: 0.0020669324988341906
# episode: 2218   score: 2.0   memory length: 364005   epsilon: 0.7173946000093043   global_step: 364005   average_q: 0.31528113481372294   average loss: 0.001996753546906132
# episode: 2219   score: 0.0   memory length: 364119   epsilon: 0.7172920000093077   global_step: 364119   average_q: 0.12193742969579864   average loss: 0.0023333520826111596
# episode: 2220   score: 0.0   memory length: 364223   epsilon: 0.7171984000093108   global_step: 364223   average_q: 0.12357784979618512   average loss: 0.002621898803996513
# episode: 2221   score: 2.0   memory length: 364398   epsilon: 0.717040900009316   global_step: 364398   average_q: 0.27415958285331726   average loss: 0.002427881198694065
# episode: 2222   score: 0.0   memory length: 364518   epsilon: 0.7169329000093195   global_step: 364518   average_q: 0.11532825008034706   average loss: 0.0025452963703476903
# episode: 2223   score: 1.0   memory length: 364679   epsilon: 0.7167880000093243   global_step: 364679   average_q: 0.20366611613990357   average loss: 0.0019907493522804322
# episode: 2224   score: 2.0   memory length: 364856   epsilon: 0.7166287000093295   global_step: 364856   average_q: 0.2136285712489974   average loss: 0.0027303773413068946
# episode: 2225   score: 2.0   memory length: 365044   epsilon: 0.7164595000093351   global_step: 365044   average_q: 0.2801813866863859   average loss: 0.002446592029724691
# episode: 2226   score: 3.0   memory length: 365250   epsilon: 0.7162741000093412   global_step: 365250   average_q: 0.19376063173257033   average loss: 0.002052458883554209
# episode: 2227   score: 0.0   memory length: 365381   epsilon: 0.7161562000093451   global_step: 365381   average_q: 0.12719434613489922   average loss: 0.0025659657686856355
# episode: 2228   score: 3.0   memory length: 365582   epsilon: 0.7159753000093511   global_step: 365582   average_q: 0.29667882198718054   average loss: 0.0021808421162805005
# episode: 2229   score: 7.0   memory length: 365973   epsilon: 0.7156234000093626   global_step: 365973   average_q: 0.16379729873688934   average loss: 0.002394967872849362
# episode: 2230   score: 0.0   memory length: 366087   epsilon: 0.715520800009366   global_step: 366087   average_q: 0.11691157467532576   average loss: 0.0015576542577228362
# episode: 2231   score: 0.0   memory length: 366193   epsilon: 0.7154254000093692   global_step: 366193   average_q: 0.12017211514823842   average loss: 0.0031784578151825183
# episode: 2232   score: 4.0   memory length: 366464   epsilon: 0.7151815000093772   global_step: 366464   average_q: 0.1782559183910764   average loss: 0.0023720928852710996
# episode: 2233   score: 3.0   memory length: 366678   epsilon: 0.7149889000093835   global_step: 366678   average_q: 0.22945062175532369   average loss: 0.0021524616392959283
# episode: 2234   score: 1.0   memory length: 366820   epsilon: 0.7148611000093877   global_step: 366820   average_q: 0.1899863748063504   average loss: 0.0027723913115064343
# episode: 2235   score: 1.0   memory length: 366977   epsilon: 0.7147198000093924   global_step: 366977   average_q: 0.2229499989634107   average loss: 0.0021924567777755416
# episode: 2236   score: 7.0   memory length: 367340   epsilon: 0.7143931000094031   global_step: 367340   average_q: 0.1900510023612293   average loss: 0.002384985298794321
# episode: 2237   score: 1.0   memory length: 367514   epsilon: 0.7142365000094083   global_step: 367514   average_q: 0.15292023550504927   average loss: 0.0029500158721595822
# episode: 2238   score: 2.0   memory length: 367684   epsilon: 0.7140835000094133   global_step: 367684   average_q: 0.20599070173852585   average loss: 0.0018197983023128471
# episode: 2239   score: 0.0   memory length: 367799   epsilon: 0.7139800000094167   global_step: 367799   average_q: 0.12702273726463317   average loss: 0.0027783326118799817
# episode: 2240   score: 4.0   memory length: 368078   epsilon: 0.713728900009425   global_step: 368078   average_q: 0.2423251107815773   average loss: 0.002035068706971281
# episode: 2241   score: 2.0   memory length: 368258   epsilon: 0.7135669000094303   global_step: 368258   average_q: 0.2715067194567786   average loss: 0.002081936788656296
# episode: 2242   score: 0.0   memory length: 368367   epsilon: 0.7134688000094336   global_step: 368367   average_q: 0.11850735709207867   average loss: 0.0021735310010876883
# episode: 2243   score: 0.0   memory length: 368482   epsilon: 0.713365300009437   global_step: 368482   average_q: 0.121574372312297   average loss: 0.002440947105819562
# episode: 2244   score: 0.0   memory length: 368597   epsilon: 0.7132618000094404   global_step: 368597   average_q: 0.13154087196225706   average loss: 0.0019357890884629855
# episode: 2245   score: 0.0   memory length: 368727   epsilon: 0.7131448000094442   global_step: 368727   average_q: 0.11679099454329564   average loss: 0.0018367353837395338
# episode: 2246   score: 2.0   memory length: 368938   epsilon: 0.7129549000094505   global_step: 368938   average_q: 0.15198768244535438   average loss: 0.0016718811111872843
# episode: 2247   score: 0.0   memory length: 369041   epsilon: 0.7128622000094536   global_step: 369041   average_q: 0.1142991133106565   average loss: 0.002732694490069017
# episode: 2248   score: 2.0   memory length: 369204   epsilon: 0.7127155000094584   global_step: 369204   average_q: 0.20082994289924763   average loss: 0.001809291126132597
# episode: 2249   score: 3.0   memory length: 369429   epsilon: 0.712513000009465   global_step: 369429   average_q: 0.2673152710331811   average loss: 0.0019692543478191105
# episode: 2250   score: 2.0   memory length: 369603   epsilon: 0.7123564000094702   global_step: 369603   average_q: 0.22361293452224512   average loss: 0.0022738966957034394
# episode: 2251   score: 3.0   memory length: 369814   epsilon: 0.7121665000094765   global_step: 369814   average_q: 0.22585902013484901   average loss: 0.002083832142191555
# episode: 2252   score: 3.0   memory length: 370047   epsilon: 0.7119568000094834   global_step: 370047   average_q: 0.2261584357642309   average loss: 0.0020135553826502017
# episode: 2253   score: 0.0   memory length: 370162   epsilon: 0.7118533000094868   global_step: 370162   average_q: 0.12151037039964095   average loss: 0.002614108436239843
# episode: 2254   score: 2.0   memory length: 370358   epsilon: 0.7116769000094926   global_step: 370358   average_q: 0.23439436329870808   average loss: 0.002463195615133855
# episode: 2255   score: 2.0   memory length: 370541   epsilon: 0.711512200009498   global_step: 370541   average_q: 0.22462860108073293   average loss: 0.0026006148590533257
# episode: 2256   score: 5.0   memory length: 370902   epsilon: 0.7111873000095087   global_step: 370902   average_q: 0.24694490647382022   average loss: 0.0027328395893232295
# episode: 2257   score: 0.0   memory length: 371003   epsilon: 0.7110964000095117   global_step: 371003   average_q: 0.12798134997339533   average loss: 0.00404863951279376
# episode: 2258   score: 3.0   memory length: 371228   epsilon: 0.7108939000095184   global_step: 371228   average_q: 0.22691303094228107   average loss: 0.0024616305304354883
# episode: 2259   score: 3.0   memory length: 371497   epsilon: 0.7106518000095263   global_step: 371497   average_q: 0.1725506601945175   average loss: 0.0023779061243269545
# episode: 2260   score: 1.0   memory length: 371635   epsilon: 0.7105276000095304   global_step: 371635   average_q: 0.17423402723194897   average loss: 0.003199591582929513
# episode: 2261   score: 4.0   memory length: 371892   epsilon: 0.710296300009538   global_step: 371892   average_q: 0.20856589194865544   average loss: 0.002820445841938395
# episode: 2262   score: 2.0   memory length: 372068   epsilon: 0.7101379000095432   global_step: 372068   average_q: 0.20321617377075282   average loss: 0.0022424204143217967
# episode: 2263   score: 3.0   memory length: 372277   epsilon: 0.7099498000095494   global_step: 372277   average_q: 0.22901299410459527   average loss: 0.002567177619055386
# episode: 2264   score: 2.0   memory length: 372511   epsilon: 0.7097392000095564   global_step: 372511   average_q: 0.23319145247467563   average loss: 0.002425519628442812
# episode: 2265   score: 1.0   memory length: 372672   epsilon: 0.7095943000095611   global_step: 372672   average_q: 0.14441634890455637   average loss: 0.0030876014539639334
# episode: 2266   score: 2.0   memory length: 372881   epsilon: 0.7094062000095673   global_step: 372881   average_q: 0.1808443135051636   average loss: 0.002858125359604233
# episode: 2267   score: 4.0   memory length: 373142   epsilon: 0.7091713000095751   global_step: 373142   average_q: 0.2801303805290968   average loss: 0.002848953867493504
# episode: 2268   score: 4.0   memory length: 373397   epsilon: 0.7089418000095826   global_step: 373397   average_q: 0.2260207390083986   average loss: 0.0029156456702028166
# episode: 2269   score: 0.0   memory length: 373526   epsilon: 0.7088257000095864   global_step: 373526   average_q: 0.11323199831238089   average loss: 0.0026779194774653025
# episode: 2270   score: 2.0   memory length: 373709   epsilon: 0.7086610000095919   global_step: 373709   average_q: 0.19860854451773596   average loss: 0.0018077316842502482
# episode: 2271   score: 1.0   memory length: 373854   epsilon: 0.7085305000095962   global_step: 373854   average_q: 0.2809754484686358   average loss: 0.002240255449653667
# episode: 2272   score: 2.0   memory length: 374020   epsilon: 0.7083811000096011   global_step: 374020   average_q: 0.22576048000749335   average loss: 0.0023549032990690263
# episode: 2273   score: 2.0   memory length: 374207   epsilon: 0.7082128000096066   global_step: 374207   average_q: 0.22828513606984346   average loss: 0.0022432625464619423
# episode: 2274   score: 2.0   memory length: 374400   epsilon: 0.7080391000096123   global_step: 374400   average_q: 0.11741719020463025   average loss: 0.002559966198108376
# episode: 2275   score: 2.0   memory length: 374598   epsilon: 0.7078609000096182   global_step: 374598   average_q: 0.25339554340550396   average loss: 0.002319389557118429
# episode: 2276   score: 2.0   memory length: 374772   epsilon: 0.7077043000096234   global_step: 374772   average_q: 0.21782287201662173   average loss: 0.0029667716241848453
# episode: 2277   score: 1.0   memory length: 374934   epsilon: 0.7075585000096282   global_step: 374934   average_q: 0.16591360282014916   average loss: 0.0029645777318409623
# episode: 2278   score: 2.0   memory length: 375134   epsilon: 0.7073785000096341   global_step: 375134   average_q: 0.31536486446857454   average loss: 0.002266260109718132
# episode: 2279   score: 3.0   memory length: 375382   epsilon: 0.7071553000096414   global_step: 375382   average_q: 0.15225188818670088   average loss: 0.002705108828899205
# episode: 2280   score: 1.0   memory length: 375556   epsilon: 0.7069987000096466   global_step: 375556   average_q: 0.2078754336669527   average loss: 0.0028012763248353757
# episode: 2281   score: 5.0   memory length: 375852   epsilon: 0.7067323000096554   global_step: 375852   average_q: 0.2331493523072552   average loss: 0.0020922776606115607
# episode: 2282   score: 0.0   memory length: 375969   epsilon: 0.7066270000096588   global_step: 375969   average_q: 0.1279837942530966   average loss: 0.003122865562934158
# episode: 2283   score: 2.0   memory length: 376166   epsilon: 0.7064497000096647   global_step: 376166   average_q: 0.21907277367441788   average loss: 0.0031173167185004572
# episode: 2284   score: 2.0   memory length: 376348   epsilon: 0.7062859000096701   global_step: 376348   average_q: 0.22625222474664122   average loss: 0.0021618760235999086
# episode: 2285   score: 1.0   memory length: 376489   epsilon: 0.7061590000096742   global_step: 376489   average_q: 0.21022802675869448   average loss: 0.0032317274634425814
# episode: 2286   score: 2.0   memory length: 376682   epsilon: 0.70598530000968   global_step: 376682   average_q: 0.2714664960772262   average loss: 0.0022642900818178355
# episode: 2287   score: 2.0   memory length: 376880   epsilon: 0.7058071000096858   global_step: 376880   average_q: 0.3223059070531768   average loss: 0.002529674922110221
# episode: 2288   score: 1.0   memory length: 377034   epsilon: 0.7056685000096904   global_step: 377034   average_q: 0.18392196162180466   average loss: 0.0025707298425606804
# episode: 2289   score: 2.0   memory length: 377212   epsilon: 0.7055083000096957   global_step: 377212   average_q: 0.20849855126959554   average loss: 0.0022943964285424157
# episode: 2290   score: 1.0   memory length: 377375   epsilon: 0.7053616000097005   global_step: 377375   average_q: 0.17447831861080568   average loss: 0.0019360816847544414
# episode: 2291   score: 1.0   memory length: 377520   epsilon: 0.7052311000097048   global_step: 377520   average_q: 0.18232222898253078   average loss: 0.0024096874143839974
# episode: 2292   score: 0.0   memory length: 377633   epsilon: 0.7051294000097081   global_step: 377633   average_q: 0.11783894922881   average loss: 0.002471021760179892
# episode: 2293   score: 2.0   memory length: 377822   epsilon: 0.7049593000097137   global_step: 377822   average_q: 0.19532302195432955   average loss: 0.0022561336800834245
# episode: 2294   score: 0.0   memory length: 377944   epsilon: 0.7048495000097174   global_step: 377944   average_q: 0.11051119277711774   average loss: 0.0018837028902289304
# episode: 2295   score: 1.0   memory length: 378091   epsilon: 0.7047172000097217   global_step: 378091   average_q: 0.18031312535409214   average loss: 0.0027571644406919338
# episode: 2296   score: 2.0   memory length: 378274   epsilon: 0.7045525000097271   global_step: 378274   average_q: 0.18124674594467455   average loss: 0.0024193541403739623
# episode: 2297   score: 1.0   memory length: 378437   epsilon: 0.704405800009732   global_step: 378437   average_q: 0.19132247128369617   average loss: 0.0018017094250124925
